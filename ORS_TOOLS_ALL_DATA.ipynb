# %%
import folium
import folium.plugins
from folium.plugins import MarkerCluster
import folium.plugins.antpath
from shapely import wkt, geometry
from ortools.constraint_solver import pywrapcp, routing_enums_pb2
import pandas as pd
import requests
import math
import json
from collections import defaultdict
import os
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 6
#       4 import folium.plugins.antpath
#       5 from shapely import wkt, geometry
# ----> 6 from ortools.constraint_solver import pywrapcp, routing_enums_pb2
#       7 import pandas as pd
#       8 import requests
#
# ModuleNotFoundError: No module named 'ortools'

# %%
url_direction = "https://ds-route-service-api.pupuk.in/ors/v2/directions/driving-hgv"

headers = {
        'Accept': 'application/json, application/geo+json, application/gpx+xml, img/png; charset=utf-8',
        'Authorization': '',
        'Content-Type': 'application/json; charset=utf-8'
    }

# request body key
units = 'km'
preference = 'recommended'

dc_map = "DC5"
num_of_dc = "45"

dataset_data = f"desa_{num_of_dc}.xlsx"
distance_list_file = f'distance_list_{num_of_dc}.json'

# Output
routes_opt_file = f"routes_final_{num_of_dc}.json"
vehicle_route_opt = f'vehicle_route_opt_{dc_map}_{num_of_dc}.json'
file_map = f"map_routes_{dc_map}_{num_of_dc}.html"

# %%
# dataset consumer handled by dc banyumas
dataset = pd.read_excel(dataset_data,sheet_name='all_dc')
pd.set_option('display.max_columns', None)
dataset.head()
# Out:
#    Unnamed: 0                         id    customers address  \
# 0        3392  GPP PURWOREJO_KEDUNGMULYO  KEDUNGMULYO       -
# 1         447        GPP PURWOREJO_BAYAN        BAYAN       -
# 2         448        GPP PURWOREJO_BAYEM        BAYEM       -
# 3        6963       GPP PURWOREJO_SRUWOH       SRUWOH       -
# 4        6964  GPP PURWOREJO_SRUWOHDUKUH  SRUWOHDUKUH       -
#
#              kabkota     provinsi  alokasi_per_bulan  lat_customers  \
# 0       KAB. CILACAP  JAWA TENGAH               4.44       -7.78104
# 1      KAB. PEMALANG  JAWA TENGAH               4.44       -7.71695
# 2    KAB. TEMANGGUNG  JAWA TENGAH               4.44       -7.73209
# 3  KAB. BANJARNEGARA  JAWA TENGAH               4.44       -7.81306
# 4        KAB. KENDAL  JAWA TENGAH               4.44       -7.75471
#
#    lon_customers nearest_plant_existing  lat_plant_existing  \
# 0        109.848          GPP PURWOREJO            -7.72268
# 1        109.942          GPP PURWOREJO            -7.72268
# 2        109.894          GPP PURWOREJO            -7.72268
# 3        109.968          GPP PURWOREJO            -7.72268
# 4        109.844          GPP PURWOREJO            -7.72268
#
#    lon_plant_existing       Urea        NPK  NPK_Kakao  Organik      Total  \
# 0            109.9468  40260.970  25706.808     15.405   3150.0  69133.183
# 1            109.9468  23799.170  17154.820      0.000    946.0  41899.990
# 2            109.9468  12594.320  19278.109     16.748   1245.0  33134.177
# 3            109.9468  17069.411  17047.748      0.000    175.0  34292.159
# 4            109.9468  32671.130  24409.096      0.000   1150.0  58230.226
#
#     Kios   Desa  %kios/desa  realisasi_penjualan_kab  jumlah_transaksi_kab  \
# 0  146.0  269.0    0.542751                29700.305                1951.0
# 1  137.0  212.0    0.646226                16031.500                1338.0
# 2   65.0  266.0    0.244361                11881.355                1491.0
# 3   72.0  266.0    0.270677                13060.500                1216.0
# 4  286.0  266.0    1.075188                18786.550                1095.0
#
#    over_under_stock_kab  realisasi_penjualan_desa_per_bulan  \
# 0             39432.878                           11.041006
# 1             25868.490                            7.562028
# 2             21252.822                            4.466675
# 3             21231.659                            4.909962
# 4             39443.676                            7.062613
#
#    jumlah_transaksi_desa_per_bulan  urea_per_bulan  NPK_per_bulan  latitude  \
# 0                         0.604399       12.472419       7.963695  -7.78104
# 1                         0.525943        9.355020       6.743247  -7.71695
# 2                         0.467105        3.945589       6.039508  -7.73209
# 3                         0.380952        5.347560       5.340773  -7.81306
# 4                         0.343045       10.235316       7.646960  -7.75471
#
#    longitude assigned_DC  DC_latitude  DC_longitude  estimasi_pengiriman  \
# 0    109.848         DC1    -7.749836     109.96055                    1
# 1    109.942         DC1    -7.749836     109.96055                    1
# 2    109.894         DC1    -7.749836     109.96055                    1
# 3    109.968         DC1    -7.749836     109.96055                    1
# 4    109.844         DC1    -7.749836     109.96055                    1
#
#    distance_to_DC_km  durations_in_min
# 0           26.97995         28.233667
# 1           11.28071         12.790833
# 2           15.74003         16.546333
# 3           11.56325         17.684333
# 4           23.07162         22.736833

# %%
data_by_dc = defaultdict(lambda: {'name': [],'coords': [], 'demands': [], 'address':[], 'provinsi':[]})

for _, row in dataset.iterrows():
    label = row['assigned_DC']
    lat = float(row['lat_customers'])
    lon = float(row['lon_customers'])
    name = str(row['customers'])
    demands = math.ceil(row['alokasi_per_bulan'])
    address = str(row['address'])
    provinsi = str(row['provinsi'])
    dc_lat = float(row['DC_latitude'])
    dc_lon = float(row['DC_longitude'])

    # Jika belum ada data untuk DC ini, tambahkan DC info ke indeks awal
    if not data_by_dc[label]['coords']:
        # Tambahkan koordinat DC di indeks awal
        data_by_dc[label]['name'].append(label)
        data_by_dc[label]['coords'].append([dc_lon, dc_lat])
        # Tambahkan demand awal untuk DC (0)
        data_by_dc[label]['demands'].append(0)
        # Tambahkan address dan provinsi awal untuk DC
        data_by_dc[label]['address'].append("-")
        data_by_dc[label]['provinsi'].append(provinsi)
    
    # Tambahkan koordinat centroid dan koordinat kios ke dalam list untuk label cluster yang sesuai
    data_by_dc[label]['name'].append(name)
    data_by_dc[label]['coords'].append([lon, lat])
    data_by_dc[label]['demands'].append(demands)
    data_by_dc[label]['address'].append(address)
    data_by_dc[label]['provinsi'].append(provinsi)

# %%
with open(distance_list_file, 'r') as f:
    distance_data = json.load(f)

distances_by_dc = {entry['DC']: entry['distances'] for entry in distance_data}

for dc, distance in data_by_dc.items():
    if dc in distances_by_dc:
        # Tambahkan jarak ke data_by_dc[dc]['distances']
        distance['distance_matrix'] = [[math.ceil(value) if value is not None else 0 for value in row] for row in distances_by_dc[dc]]
    else:
        # Jika DC tidak ditemukan, tambahkan jarak kosong
        distance['distance_matrix'] = []

# %%
# Dipakai jika belum mendapatkan data jarak
# headers = {
#         'Accept': 'application/json, application/geo+json, application/gpx+xml, img/png; charset=utf-8',
#         'Authorization': '',
#         'Content-Type': 'application/json; charset=utf-8'
#     }

# url = f'http://34.34.220.116:8082/ors/v2/matrix/driving-hgv'


# for label, data in data_by_dc.items():
#     village_coords = data['coords']

#     request = {'locations': village_coords,
#             'profile': 'driving-hgv',
#             'metrics': ['distance'],
#             'units':'m'
#             }

#     try:
#         # Mengirim permintaan POST
#         response = requests.post(url=url, headers=headers, json=request)
#         response.raise_for_status()  # Raise error jika status code bukan 2xx

#         # Parsing hasil
#         village_matrix = response.json()
#         distances = village_matrix.get('distances', [])

#         processed_matrix = [[math.ceil(value) if value is not None else 0 for value in row] for row in distances]

#         # Simpan hasil ke data_by_dc
#         data_by_dc[label]['distance_matrix'] = processed_matrix

#         print("{} Calculated {}x{} routes.".format(label,len(distances), len(distances[0])))

#     except requests.exceptions.RequestException as e:
#         response = response.json()
#         print("An error occurred while making the request:")
#         print(f"Code: {response['error']['code']}\nMessage: {response['error']['message']}")

#     except KeyError as e:
#         print("Response format error. Missing key:", e)

#     except Exception as e:
#         print("An unexpected error occurred:", e)

# %%
def split_demands(data):
    max_capacity = data["vehicle_capacities"][0]  # Asumsi semua kendaraan memiliki kapasitas yang sama
    new_name = []
    new_address = []
    new_province = []

    new_demands = []
    new_distance_matrix = []
    new_locations = []
    mapping = []  # Untuk melacak indeks baru ke indeks asli dan sub bagian
    
    for i, demand in enumerate(data["demands"]):
        if demand > max_capacity:
            # Hitung jumlah split yang diperlukan
            num_splits = -(-demand // max_capacity)  # Ceiling division
            num_splits = int(num_splits)
            split_values = [max_capacity] * (num_splits - 1) + [demand % max_capacity or max_capacity]
            
            # Tambahkan demand hasil split
            for part, split_value in enumerate(split_values):
                new_demands.append(split_value)
                mapping.append((i, part + 1))  # (konsumen asli, bagian ke-n)
            
            # Duplikasi baris dan kolom di distance_matrix untuk konsumen ini
            for _ in split_values:
                new_distance_matrix.append(data["distance_matrix"][i])
            
            for _ in split_values:
                new_locations.append(data['locations'][i])

            for _ in split_values:
                new_name.append(data['name'][i])

        else:
            new_demands.append(demand)
            mapping.append((i, 0))  # (konsumen asli, tidak di-split)

            new_name.append(data['name'][i])
            new_address.append(data['address'][i])
            new_province.append(data['province'][i])
            
            new_distance_matrix.append(data["distance_matrix"][i])
            new_locations.append(data['locations'][i])
    
    # Perbarui distance_matrix dengan menambahkan kolom baru
    updated_matrix = []
    for i, row in enumerate(new_distance_matrix):
        updated_row = []
        for j, _ in enumerate(new_distance_matrix):
            if i < len(mapping) and j < len(mapping):
                updated_row.append(data["distance_matrix"][mapping[i][0]][mapping[j][0]])  # Ambil jarak dari indeks asli
            else:
                updated_row.append(0)  # Atur jarak untuk posisi baru yang di-split
        updated_matrix.append(updated_row)

    
    return {
        "name": new_name,
        "address": new_address,
        "province": new_province,
        "distance_matrix": updated_matrix,
        "demands": new_demands,
        'locations': new_locations,
        "vehicle_capacities": data["vehicle_capacities"],
        "num_vehicles": data["num_vehicles"],
        "depot": data["depot"],
        "mapping": mapping,
    }

# %%
# data insert
# (When there's only one vehicle, it reduces to the Traveling Salesperson Problem.)
# A better way to define optimal routes is to minimize the length of the longest single route among all vehicles. This is the right definition if the goal is to complete all deliveries as soon as possible.
# djikstra, mencari minimum weight dari satu titik ke titik lain. TSP = djikstra + rute kembali. VRP = TSP dengan vehicle > 1

num_vehicle = 2000
vehicle_capacity = 20000 # satuannya bisa apapun
def create_data_model():
    all_data = {}
    """Stores the data for the problem."""
    for dc, dc_data in data_by_dc.items():
        data = {}
        data['name'] = dc_data['name']
        data['address'] = dc_data['address']
        data['province'] = dc_data['provinsi']
        data["locations"] = dc_data['coords']
        data['distance_matrix'] = dc_data['distance_matrix']
        data["demands"] = dc_data['demands']
        data["vehicle_capacities"] = [vehicle_capacity for _ in range(num_vehicle)]
        data["num_vehicles"] = num_vehicle
        data["depot"] = 0
        
        # Masukkan data ke dictionary hasil dengan key sesuai DC
        all_data[dc] = split_demands(data)
    
    return all_data

# %%
"""Capacited Vehicles Routing Problem (CVRP) using OR-TOOLS."""

result_data = []
def print_solution(data, manager, routing, solution):
    """Prints solution on console."""
    mapping = data["mapping"]
    print(f"Objective: {solution.ObjectiveValue()}")
    total_distance = 0
    total_load = 0
    total_trips = 0
    vehicle_id = 0

    for vehicle_id in range(data["num_vehicles"]):
        index = routing.Start(vehicle_id)
        plan_output = f"Route for vehicle {vehicle_id}:\n"
        route_distance = 0
        route_load = 0
        remaining_load_capacity = data["vehicle_capacities"][vehicle_id]  # Track the remaining capacity
        
        while not routing.IsEnd(index):
            node_index = manager.IndexToNode(index)
            consumer_original, split_part = mapping[node_index]  # Ambil indeks asli dan bagian split
            consumer_label = f"{consumer_original}-{split_part}"

            route_load += data["demands"][node_index]
            remaining_load_capacity -= data["demands"][node_index]  # Subtract the demand from remaining capacity

            if node_index == data['depot']:
                plan_output += f"Depot: {data['name'][node_index]} | Cumm_Load: {route_load} | rem_capacity: {remaining_load_capacity} -> "
            elif data['demands'][node_index] == 0:
                index = solution.Value(routing.NextVar(index))
                continue
            else:
                plan_output += f"Consumer: {data['name'][node_index]} | Demand: {data['demands'][node_index]} | Cumm_Load: {route_load} | rem_capacity: {remaining_load_capacity} -> "

            previous_index = index
            index = solution.Value(routing.NextVar(index))
            route_distance += routing.GetArcCostForVehicle(
                previous_index, index, vehicle_id
            )

            # Ambil data lokasi pertama dan kedua
            lat_current, lon_current = data['locations'][node_index]  # Koordinat untuk node saat ini
            # lat_next, lon_next = data['locations'][index]  # Koordinat untuk node berikutnya

            # Append data for DataFrame
            # Append current and next node to result_data
            if route_load != 0:
                result_data.append({
                    "Vehicle": vehicle_id,
                    "Depot": data['depot'],
                    "Node": consumer_label,
                    "Demand": data["demands"][node_index],
                    "Cumulative Load": route_load,
                    "Remaining Capacity": remaining_load_capacity,
                    "Distance": route_distance,
                    "Current Node": node_index,
                    "Current_lat": lat_current,
                    "Current_lon": lon_current,
                    "Next Node": index,
                })
        # After visiting all customers, return to depot (node 0)
        node_index = manager.IndexToNode(previous_index)
        consumer_original, split_part = mapping[node_index]
        # route_distance += routing.GetArcCostForVehicle(previous_index, index, vehicle_id)

        if route_load != 0:
            plan_output += f"\nLast Customer: {data['name'][node_index]} Load({route_load})\n"
            plan_output += f"Distance of the route: {route_distance}m\n"
            plan_output += f"Load of the route: {route_load}\n"
            total_trips += 1
            total_distance += route_distance
            total_load += route_load
            print(plan_output)

    print(f"Total number of trips: {total_trips}")
    print(f"Total distance of all routes: {total_distance}m")
    print(f"Total load of all routes: {total_load}")

def get_routes(solution, routing, manager, dc, data, json_file='routes.json'):
    total_distance = 0
    total_load = 0
    total_trips = 0

    routes = {}

    if dc not in routes:
        routes[dc] = {"summary": None, "routes": {}}

    if "routes" not in routes[dc]:
        routes[dc]["routes"] = {}

    for vehicle_id in range(routing.vehicles()):
        index = routing.Start(vehicle_id)
        route_distance = 0
        route_load = 0
        remaining_load_capacity = data["vehicle_capacities"][vehicle_id]
        route = []

        while not routing.IsEnd(index):
            node_index = manager.IndexToNode(index)
            route_load += data["demands"][node_index]
            remaining_load_capacity -= data["demands"][node_index]
            if data['demands'][node_index] != 0 or node_index == data['depot']:
                data_route = {
                    'name': data['name'][node_index],
                    'location': data['locations'][node_index],
                    'remaining_load_capacity': remaining_load_capacity,
                    'route_load': route_load,
                    'demands': data['demands'][node_index],
                }
                route.append({
                    'routing': data_route
                })

                previous_index = index
                index = solution.Value(routing.NextVar(index))
                route_distance += routing.GetArcCostForVehicle(
                previous_index, index, vehicle_id
                )

            else:
                index = solution.Value(routing.NextVar(index))
                continue
        node_index = manager.IndexToNode(index)
        end_route = {
            'name': data['name'][node_index],
            'location': data['locations'][node_index],
            'remaining_load_capacity': remaining_load_capacity,
            'route_load': route_load,
            'demands': data['demands'][node_index],
        }
        route.append({
            'routing': end_route
        })

        if route_load != 0:
            total_distance += route_distance
            total_load += route_load
            total_trips += 1

        # Simpan ke dalam dictionary hanya jika rute memiliki lebih dari dua lokasi (depot + customer)

        if len(route) != 2:
            routes[dc]["routes"][vehicle_id] = route
    # Tambahkan node terakhir (end/depot)
    node_index = manager.IndexToNode(index)
    summary = {
        'distance': total_distance,
        'load':total_load,
        'trips': total_trips
    }

    routes[dc]["summary"] = summary
    

    update_routes_json(dc, routes, json_file)

def update_routes_json(dc, routes, json_file='routes.json'):
    # Cek apakah file JSON sudah ada
    if os.path.exists(json_file):
        # Jika ada, baca data yang ada dalam file
        with open(json_file, 'r') as f:
            data = json.load(f)
    else:
        # Jika tidak ada, buat file kosong dengan struktur dasar
        data = {}

    # Jika dc belum ada dalam data, buatkan list baru untuk dc
    if dc not in data:
        data[dc] = {}
        data[dc].update(routes[dc])
            # Simpan kembali ke dalam file JSON
        with open(json_file, 'w') as f:
            json.dump(data, f, indent=4)

        print(f"Routes data for {dc} successfuly inserted in {json_file}")
    else:
        print(f"{dc} optimization already in data!")


def main():
    """Solve the CVRP problem."""
    
    data = create_data_model()

    for dc, dc_data in data.items():
        # Create the routing index manager.
        manager = pywrapcp.RoutingIndexManager(
            len(dc_data["distance_matrix"]), dc_data["num_vehicles"], dc_data["depot"]
        )

        # Create Routing Model.
        routing = pywrapcp.RoutingModel(manager)

        # distance_matrix = compute_haversine_distance_matrix(dc_data['locations'])
        # Create and register a transit callback (menghitung jarak antar dua titik).
        def distance_callback(from_index, to_index):
            """Returns the distance between the two nodes."""
            # Convert from routing variable Index to distance matrix NodeIndex.
            from_node = manager.IndexToNode(from_index)
            to_node = manager.IndexToNode(to_index)
            return dc_data["distance_matrix"][from_node][to_node]

        transit_callback_index = routing.RegisterTransitCallback(distance_callback)


        # Define cost of each arc.
        routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

        # Add Capacity constraint.
        def demand_callback(from_index):
            """Returns the demand of the node."""
            # Convert from routing variable Index to demands NodeIndex.
            from_node = manager.IndexToNode(from_index)
            return dc_data["demands"][from_node]

        demand_callback_index = routing.RegisterUnaryTransitCallback(demand_callback)
        routing.AddDimensionWithVehicleCapacity(
            demand_callback_index,
            0,  # null capacity slack
            dc_data["vehicle_capacities"],  # vehicle maximum capacities
            True,  # start cumul to zero
            "Capacity",
        )

        # Setting first solution heuristic.
        search_parameters = pywrapcp.DefaultRoutingSearchParameters()

        # menggunakan pendekatan pencarian Guided_local_search untuk menghindari pengambilan local optimum
        # search_parameters.first_solution_strategy = (
        #     routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC
        # )

        search_parameters.local_search_metaheuristic = (
            routing_enums_pb2.LocalSearchMetaheuristic.GUIDED_LOCAL_SEARCH
        )
        search_parameters.time_limit.FromSeconds(15)
        # search_parameters.log_search = True


        if os.path.exists(routes_opt_file):
            # Jika ada, baca data yang ada dalam file
            with open(routes_opt_file, 'r') as f:
                data_json = json.load(f)
        else:
            # Jika tidak ada, buat file kosong dengan struktur dasar
            data_json = {}

        # Jika dc belum ada dalam data_json, buatkan list baru untuk dc
        if dc not in data_json:
            print(f"Calculating {dc}...")
            solution = routing.SolveWithParameters(search_parameters)
            
            # # Print solution on console.
            # if solution:
            #     print_solution(dc_data, manager, routing, solution)
            # else:
            #     print('No Solution Found!')
                
            if not solution:
                print(f'{dc} No Solution Found!')
                # continue
            get_routes(solution, routing, manager, dc, dc_data, routes_opt_file)
        else:            
            print(f"{dc} optimization already in data!")
            # continue


        print(f"{dc} end of program!")

if __name__ == "__main__":
    main()
# Out:
# DC1 optimization already in data!
# DC1 end of program!
# DC2 optimization already in data!
# DC2 end of program!
# DC3 optimization already in data!
# DC3 end of program!
# DC4 optimization already in data!
# DC4 end of program!
# DC5 optimization already in data!
# DC5 end of program!
# DC6 optimization already in data!
# DC6 end of program!
# DC7 optimization already in data!
# DC7 end of program!
# DC8 optimization already in data!
# DC8 end of program!
# DC9 optimization already in data!
# DC9 end of program!
# DC10 optimization already in data!
# DC10 end of program!
# DC11 optimization already in data!
# DC11 end of program!
# DC12 optimization already in data!
# DC12 end of program!
# DC13 optimization already in data!
# DC13 end of program!
# DC14 optimization already in data!
# DC14 end of program!
# DC15 optimization already in data!
# DC15 end of program!
# DC16 optimization already in data!
# DC16 end of program!
# DC17 optimization already in data!
# DC17 end of program!
# DC18 optimization already in data!
# DC18 end of program!
# DC19 optimization already in data!
# DC19 end of program!
# DC20 optimization already in data!
# DC20 end of program!
# DC21 optimization already in data!
# DC21 end of program!
# DC22 optimization already in data!
# DC22 end of program!
# DC23 optimization already in data!
# DC23 end of program!
# DC24 optimization already in data!
# DC24 end of program!
# DC25 optimization already in data!
# DC25 end of program!
# DC26 optimization already in data!
# DC26 end of program!
# DC27 optimization already in data!
# DC27 end of program!
# DC28 optimization already in data!
# DC28 end of program!
# DC29 optimization already in data!
# DC29 end of program!
# DC30 optimization already in data!
# DC30 end of program!
# DC31 optimization already in data!
# DC31 end of program!
# DC32 optimization already in data!
# DC32 end of program!
# DC33 optimization already in data!
# DC33 end of program!
# DC34 optimization already in data!
# DC34 end of program!
# DC35 optimization already in data!
# DC35 end of program!
# DC36 optimization already in data!
# DC36 end of program!
# DC37 optimization already in data!
# DC37 end of program!
# DC38 optimization already in data!
# DC38 end of program!
# DC39 optimization already in data!
# DC39 end of program!
# DC40 optimization already in data!
# DC40 end of program!
# DC41 optimization already in data!
# DC41 end of program!
# DC42 optimization already in data!
# DC42 end of program!
# DC43 optimization already in data!
# DC43 end of program!
# DC44 optimization already in data!
# DC44 end of program!
# DC45 optimization already in data!
# DC45 end of program!

# %%
with open(routes_opt_file, "r") as json_file:
    routes = json.load(json_file)

coordinates_dict = {}

for dc, dc_data in routes.items():
    coordinates_dict[dc] = {}
    route = dc_data['routes']
    for vehicle_id, path in route.items():
        coordinates_list = [(stop['routing']['location'][0], stop['routing']['location'][1]) for stop in path]
        coordinates_dict[dc][str(vehicle_id)] = coordinates_list

# %%
total_trips = 0
total_distance = 0
total_load = 0
for dc, vehicle_data in routes.items():  # Iterasi level pertama (key: DC45, value: dictionary)
    distance = vehicle_data['summary']['distance']
    load = vehicle_data['summary']['load']
    trips = vehicle_data['summary']['trips']
    print(f"{dc}, load: {load}, Trips: {trips}")
    total_trips += trips
    total_distance += distance
    total_load += load

print("\nCalculated based on OR-TOOLS")
print(f"Total trips: {total_trips}")
print(f"Total distance: {total_distance} meter")
print(f"Total Load: {total_load} Ton")
# Out:
# DC1, load: 1835, Trips: 1
# DC2, load: 4213, Trips: 1
# DC3, load: 1852, Trips: 1
# DC4, load: 3842, Trips: 1
# DC5, load: 2850, Trips: 1
# DC6, load: 2709, Trips: 1
# DC7, load: 3240, Trips: 1
# DC8, load: 1722, Trips: 1
# DC9, load: 3675, Trips: 1
# DC10, load: 4017, Trips: 1
# DC11, load: 4122, Trips: 1
# DC12, load: 3804, Trips: 2
# DC13, load: 5068, Trips: 1
# DC14, load: 2545, Trips: 1
# DC15, load: 2076, Trips: 1
# DC16, load: 3399, Trips: 1
# DC17, load: 2207, Trips: 1
# DC18, load: 5933, Trips: 1
# DC19, load: 5846, Trips: 1
# DC20, load: 2290, Trips: 1
# DC21, load: 3920, Trips: 1
# DC22, load: 3802, Trips: 1
# DC23, load: 1542, Trips: 1
# DC24, load: 2172, Trips: 1
# DC25, load: 3195, Trips: 1
# DC26, load: 2853, Trips: 1
# DC27, load: 2156, Trips: 1
# DC28, load: 1844, Trips: 1
# DC29, load: 3787, Trips: 1
# DC30, load: 5991, Trips: 1
# DC31, load: 1931, Trips: 2
# DC32, load: 2185, Trips: 1
# DC33, load: 2577, Trips: 1
# DC34, load: 2242, Trips: 2
# DC35, load: 2373, Trips: 1
# DC36, load: 2436, Trips: 1
# DC37, load: 3538, Trips: 1
# DC38, load: 3360, Trips: 1
# DC39, load: 2549, Trips: 1
# DC40, load: 1997, Trips: 1
# DC41, load: 3165, Trips: 1
# DC42, load: 3051, Trips: 1
# DC43, load: 2506, Trips: 1
# DC44, load: 4302, Trips: 1
# DC45, load: 3236, Trips: 1
#
# Calculated based on OR-TOOLS
# Total trips: 48
# Total distance: 27931086 meter
# Total Load: 139955 Ton

# %%
def decode_polyline(polyline, is3d=False):
    """Decodes a Polyline string into a GeoJSON geometry.
    :param polyline: An encoded polyline, only the geometry.
    :type polyline: string
    :param is3d: Specifies if geometry contains Z component.
    :type is3d: boolean
    :returns: GeoJSON Linestring geometry
    :rtype: dict
    """
    points = []
    index = lat = lng = z = 0

    while index < len(polyline):
        result = 1
        shift = 0
        while True:
            b = ord(polyline[index]) - 63 - 1
            index += 1
            result += b << shift
            shift += 5
            if b < 0x1F:
                break
        lat += (~result >> 1) if (result & 1) != 0 else (result >> 1)

        result = 1
        shift = 0
        while True:
            b = ord(polyline[index]) - 63 - 1
            index += 1
            result += b << shift
            shift += 5
            if b < 0x1F:
                break
        lng += ~(result >> 1) if (result & 1) != 0 else (result >> 1)

        if is3d:
            result = 1
            shift = 0
            while True:
                b = ord(polyline[index]) - 63 - 1
                index += 1
                result += b << shift
                shift += 5
                if b < 0x1F:
                    break
            if (result & 1) != 0:
                z += ~(result >> 1)
            else:
                z += result >> 1

            points.append(
                [
                    round(lng * 1e-5, 6),
                    round(lat * 1e-5, 6),
                    round(z * 1e-2, 1),
                ]
            )

        else:
            points.append([round(lng * 1e-5, 6), round(lat * 1e-5, 6)])

    geojson = {u"type": u"LineString", u"coordinates": points}

    return geojson

# %% [markdown]
# ## Menggambarkan rute per DC

# %%
data = create_data_model()
data_dc = dataset[dataset['assigned_DC'] == dc_map]
data_dc
# Out:
#      Unnamed: 0                                 id       customers address  \
# 684        8194     GD BGR CANDI SEMARANG_WONOSARI        WONOSARI       -
# 685        8218         BGR JENARSARI_WONOTENGGANG    WONOTENGGANG       -
# 686        8164  GD BGR CANDI SEMARANG_WONOPLUMBON     WONOPLUMBON       -
# 687        3665       Kendal - Wonorejo_KERTOMULYO      KERTOMULYO       -
# 688        4823    Kendal - Wonorejo_NGAMPEL WETAN   NGAMPEL WETAN       -
# ..          ...                                ...             ...     ...
# 868        1787              BGR JENARSARI_GONDANG         GONDANG       -
# 869        6489        BGR JENARSARI_SENDANGDAWUNG   SENDANGDAWUNG       -
# 870        6488       BGR JENARSARI_SENDANGDAWUHAN  SENDANGDAWUHAN       -
# 871        8161     GD BGR CANDI SEMARANG_WONOLOPO        WONOLOPO       -
# 872        8175         Kendal - Wonorejo_WONOREJO        WONOREJO       -
#
#                kabkota     provinsi  alokasi_per_bulan  lat_customers  \
# 684      KAB. PEMALANG  JAWA TENGAH               1.22       -6.97933
# 685         KAB. BLORA  JAWA TENGAH              16.97       -6.95100
# 686         KAB. BLORA  JAWA TENGAH               1.22       -7.03920
# 687        KAB. KLATEN  JAWA TENGAH              16.97       -6.98042
# 688        KAB. KENDAL  JAWA TENGAH              16.97       -6.97953
# ..                 ...          ...                ...            ...
# 868  KAB. BANJARNEGARA  JAWA TENGAH              16.97       -6.93350
# 869       KAB. CILACAP  JAWA TENGAH              16.97       -6.92006
# 870  KAB. BANJARNEGARA  JAWA TENGAH              16.97       -6.93454
# 871      KAB. WONOGIRI  JAWA TENGAH               1.22       -7.05165
# 872         KAB. BLORA  JAWA TENGAH              16.97       -6.92679
#
#      lon_customers nearest_plant_existing  lat_plant_existing  \
# 684        110.309  GD BGR CANDI SEMARANG            -7.01446
# 685        110.087          BGR JENARSARI            -6.95329
# 686        110.285  GD BGR CANDI SEMARANG            -7.01446
# 687        110.203      Kendal - Wonorejo            -6.94013
# 688        110.194      Kendal - Wonorejo            -6.94013
# ..             ...                    ...                 ...
# 868        110.138          BGR JENARSARI            -6.95329
# 869        110.096          BGR JENARSARI            -6.95329
# 870        110.074          BGR JENARSARI            -6.95329
# 871        110.306  GD BGR CANDI SEMARANG            -7.01446
# 872        110.262      Kendal - Wonorejo            -6.94013
#
#      lon_plant_existing       Urea        NPK  NPK_Kakao  Organik       Total  \
# 684            110.3477  23799.170  17154.820      0.000    946.0   41899.990
# 685            110.1013  65815.932  50754.146      0.000  40000.0  156570.078
# 686            110.3477  65815.932  50754.146      0.000  40000.0  156570.078
# 687            110.2557  23536.540  16313.995      0.000   2906.0   42756.535
# 688            110.2557  32671.130  24409.096      0.000   1150.0   58230.226
# ..                  ...        ...        ...        ...      ...         ...
# 868            110.1013  17069.411  17047.748      0.000    175.0   34292.159
# 869            110.1013  40260.970  25706.808     15.405   3150.0   69133.183
# 870            110.1013  17069.411  17047.748      0.000    175.0   34292.159
# 871            110.3477  35313.661  33175.433     89.095   4466.0   73044.189
# 872            110.2557  65815.932  50754.146      0.000  40000.0  156570.078
#
#       Kios   Desa  %kios/desa  realisasi_penjualan_kab  jumlah_transaksi_kab  \
# 684  137.0  212.0    0.646226                16031.500                1338.0
# 685  366.0  271.0    1.350554                58990.675                2259.0
# 686  366.0  271.0    1.350554                58990.675                2259.0
# 687  156.0  391.0    0.398977                10453.550                 782.0
# 688  286.0  266.0    1.075188                18786.550                1095.0
# ..     ...    ...         ...                      ...                   ...
# 868   72.0  266.0    0.270677                13060.500                1216.0
# 869  146.0  269.0    0.542751                29700.305                1951.0
# 870   72.0  266.0    0.270677                13060.500                1216.0
# 871  168.0  251.0    0.669323                18539.150                1514.0
# 872  366.0  271.0    1.350554                58990.675                2259.0
#
#      over_under_stock_kab  realisasi_penjualan_desa_per_bulan  \
# 684             25868.490                            7.562028
# 685             97579.403                           21.767777
# 686             97579.403                           21.767777
# 687             32302.985                            2.673542
# 688             39443.676                            7.062613
# ..                    ...                                 ...
# 868             21231.659                            4.909962
# 869             39432.878                           11.041006
# 870             21231.659                            4.909962
# 871             54505.039                            7.386116
# 872             97579.403                           21.767777
#
#      jumlah_transaksi_desa_per_bulan  urea_per_bulan  NPK_per_bulan  latitude  \
# 684                         0.525943        9.355020       6.743247  -6.97933
# 685                         0.694649       20.238601      15.607056  -6.95100
# 686                         0.694649       20.238601      15.607056  -7.03920
# 687                         0.166667        5.016313       3.476981  -6.98042
# 688                         0.343045       10.235316       7.646960  -6.97953
# ..                               ...             ...            ...       ...
# 868                         0.380952        5.347560       5.340773  -6.93350
# 869                         0.604399       12.472419       7.963695  -6.92006
# 870                         0.380952        5.347560       5.340773  -6.93454
# 871                         0.502656       11.724323      11.014420  -7.05165
# 872                         0.694649       20.238601      15.607056  -6.92679
#
#      longitude assigned_DC  DC_latitude  DC_longitude  estimasi_pengiriman  \
# 684    110.309         DC5    -6.961605    110.159086                    1
# 685    110.087         DC5    -6.961605    110.159086                    3
# 686    110.285         DC5    -6.961605    110.159086                    1
# 687    110.203         DC5    -6.961605    110.159086                    3
# 688    110.194         DC5    -6.961605    110.159086                    3
# ..         ...         ...          ...           ...                  ...
# 868    110.138         DC5    -6.961605    110.159086                    3
# 869    110.096         DC5    -6.961605    110.159086                    3
# 870    110.074         DC5    -6.961605    110.159086                    3
# 871    110.306         DC5    -6.961605    110.159086                    1
# 872    110.262         DC5    -6.961605    110.159086                    3
#
#      distance_to_DC_km  durations_in_min
# 684           24.93482         24.233667
# 685           16.19117         16.235167
# 686           33.45635         36.947667
# 687           11.25900         14.985667
# 688            9.26362         11.656667
# ..                 ...               ...
# 868            9.91705         11.655500
# 869           18.97578         24.106000
# 870           19.13504         20.152500
# 871           34.47528         38.592333
# 872           19.49504         25.091167
#
# [189 rows x 35 columns]

# %%
# See what a 'random' tour would have been
coords = data[dc_map]['locations']
coords.append(coords[0])


request = {'coordinates': coords,
           'geometry': 'true',
           'radiuses':-1,
           'preference': preference,
           'units':units
           }

random_route = requests.post(url=url_direction,headers=headers,json=request)
random_route = random_route.json()
random_route = [random_route]
random_route
# Out:
# [{'bbox': [110.011444, -7.117238, 110.394297, -6.864065],
#   'routes': [{'summary': {'distance': 3957.887, 'duration': 283593.1999999998},
#     'segments': [{'distance': 24.935,
#       'duration': 1454.0,
#       'steps': [{'distance': 0.519,
#         'duration': 89.2,
#         'type': 11,
#         'instruction': 'Head southwest',
#         'name': '-',
#         'way_points': [0, 5]},
#        {'distance': 5.219,
#         'duration': 321.1,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [5, 137]},
#        {'distance': 2.205,
#         'duration': 143.0,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [137, 211]},
#        {'distance': 0.919,
#         'duration': 41.3,
#         'type': 1,
#         'instruction': 'Turn right onto Jalan Tentara Pelajar',
#         'name': 'Jalan Tentara Pelajar',
#         'way_points': [211, 224]},
#        {'distance': 14.842,
#         'duration': 667.8,
#         'type': 1,
#         'instruction': 'Turn right onto Jalan Raya Kendal-Semarang, 1',
#         'name': 'Jalan Raya Kendal-Semarang, 1',
#         'way_points': [224, 450]},
#        {'distance': 0.402,
#         'duration': 22.7,
#         'type': 6,
#         'instruction': 'Continue straight onto Jalan Jenderal Urip Sumoharjo, 1',
#         'name': 'Jalan Jenderal Urip Sumoharjo, 1',
#         'way_points': [450, 460]},
#        {'distance': 0.631,
#         'duration': 123.5,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [460, 474]},
#        {'distance': 0.198,
#         'duration': 45.4,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [474, 481]},
#        {'distance': 0.0,
#         'duration': 0.0,
#         'type': 10,
#         'instruction': 'Arrive at your destination, on the left',
#         'name': '-',
#         'way_points': [481, 481]}]},
#      {'distance': 31.433,
#       'duration': 1597.3,
#       'steps': [{'distance': 0.198,
#         'duration': 45.4,
#         'type': 11,
#         'instruction': 'Head southeast',
#         'name': '-',
#         'way_points': [481, 488]},
#        {'distance': 0.631,
#         'duration': 123.5,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [488, 502]},
#        {'distance': 14.444,
#         'duration': 649.9,
#         'type': 0,
#         'instruction': 'Turn left onto Jalan Jenderal Urip Sumoharjo, 1',
#         'name': 'Jalan Jenderal Urip Sumoharjo, 1',
#         'way_points': [502, 726]},
#        {'distance': 3.316,
#         'duration': 149.2,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [726, 778]},
#        {'distance': 11.838,
#         'duration': 532.7,
#         'type': 7,
#         'instruction': 'Enter the roundabout and take the 1st exit onto Jalan Tentara Pelajar',
#         'name': 'Jalan Tentara Pelajar',
#         'exit_number': 1,
#         'way_points': [778, 949]},
#        {'distance': 0.116,
#         'duration': 5.2,
#         'type': 13,
#         'instruction': 'Keep right onto 1',
#         'name': '1',
#         'way_points': [949, 953]},
#        {'distance': 0.093,
#         'duration': 4.2,
#         'type': 3,
#         'instruction': 'Turn sharp right onto Jalan Utama, 1',
#         'name': 'Jalan Utama, 1',
#         'way_points': [953, 956]},
#        {'distance': 0.504,
#         'duration': 44.2,
#         'type': 0,
#         'instruction': 'Turn left onto Rowosari',
#         'name': 'Rowosari',
#         'way_points': [956, 962]},
#        {'distance': 0.294,
#         'duration': 43.0,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [962, 968]},
#        {'distance': 0.0,
#         'duration': 0.0,
#         'type': 10,
#         'instruction': 'Arrive at your destination, on the right',
#         'name': '-',
#         'way_points': [968, 968]}]},
#      {'distance': 41.061,
#       'duration': 2421.0,
#       'steps': [{'distance': 0.294,
#         'duration': 43.0,
#         'type': 11,
#         'instruction': 'Head east',
#         'name': '-',
#         'way_points': [968, 974]},
#        {'distance': 0.479,
#         'duration': 38.3,
#         'type': 1,
#         'instruction': 'Turn right onto Rowosari',
#         'name': 'Rowosari',
#         'way_points': [974, 979]},
#        {'distance': 0.022,
#         'duration': 5.2,
#         'type': 0,
#         'instruction': 'Turn left onto Rowosari',
#         'name': 'Rowosari',
#         'way_points': [979, 980]},
#        {'distance': 9.931,
#         'duration': 446.8,
#         'type': 0,
#         'instruction': 'Turn left onto Jalan Raya Batang-Kendal, 1',
#         'name': 'Jalan Raya Batang-Kendal, 1',
#         'way_points': [980, 1118]},
#        {'distance': 0.382,
#         'duration': 24.2,
#         'type': 13,
#         'instruction': 'Keep right',
#         'name': '-',
#         'way_points': [1118, 1130]},
#        {'distance': 0.083,
#         'duration': 3.7,
#         'type': 12,
#         'instruction': 'Keep left',
#         'name': '-',
#         'way_points': [1130, 1133]},
#        {'distance': 1.926,
#         'duration': 86.7,
#         'type': 2,
#         'instruction': 'Turn sharp left onto Jalan Tentara Pelajar',
#         'name': 'Jalan Tentara Pelajar',
#         'way_points': [1133, 1158]},
#        {'distance': 0.101,
#         'duration': 4.6,
#         'type': 7,
#         'instruction': 'Enter the roundabout and take the 2nd exit',
#         'name': '-',
#         'exit_number': 2,
#         'way_points': [1158, 1164]},
#        {'distance': 3.25,
#         'duration': 146.2,
#         'type': 6,
#         'instruction': 'Continue straight onto Jalan Tentara Pelajar',
#         'name': 'Jalan Tentara Pelajar',
#         'way_points': [1164, 1215]},
#        {'distance': 14.219,
#         'duration': 639.8,
#         'type': 1,
#         'instruction': 'Turn right onto Jalan Raya Kendal-Semarang, 1',
#         'name': 'Jalan Raya Kendal-Semarang, 1',
#         'way_points': [1215, 1429]},
#        {'distance': 0.634,
#         'duration': 32.0,
#         'type': 6,
#         'instruction': 'Continue straight onto Jalan Jenderal Urip Sumoharjo, 1',
#         'name': 'Jalan Jenderal Urip Sumoharjo, 1',
#         'way_points': [1429, 1440]},
#        {'distance': 3.237,
#         'duration': 246.5,
#         'type': 0,
#         'instruction': 'Turn left onto Jalan Koptu Suyono',
#         'name': 'Jalan Koptu Suyono',
#         'way_points': [1440, 1499]},
#        {'distance': 1.632,
#         'duration': 124.0,
#         'type': 3,
#         'instruction': 'Turn sharp right onto Jalan Anyar Gondoriyo Wates',
#         'name': 'Jalan Anyar Gondoriyo Wates',
#         'way_points': [1499, 1536]},
#        {'distance': 3.674,
#         'duration': 281.5,
#         'type': 6,
#         'instruction': 'Continue straight onto Jalan Kiai Padak',
#         'name': 'Jalan Kiai Padak',
#         'way_points': [1536, 1622]},
#        {'distance': 0.856,
#         'duration': 205.3,
#         'type': 1,
#         'instruction': 'Turn right onto Jalan Dukuh Sapen',
#         'name': 'Jalan Dukuh Sapen',
#         'way_points': [1622, 1643]},
#        {'distance': 0.257,
#         'duration': 61.7,
#         'type': 0,
#         'instruction': 'Turn left onto Jalan Dukuh Sapen',
#         'name': 'Jalan Dukuh Sapen',
#         'way_points': [1643, 1653]},
#        {'distance': 0.027,
#         'duration': 9.6,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [1653, 1654]},
#        {'distance': 0.061,
#         'duration': 21.8,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [1654, 1655]},
#        {'distance': 0.0,
#         'duration': 0.0,
#         'type': 10,
#         'instruction': 'Arrive at your destination, on the right',
#         'name': '-',
#         'way_points': [1655, 1655]}]},
#      {'distance': 22.585,
#       'duration': 1888.9,
#       'steps': [{'distance': 0.061,
#         'duration': 21.8,
#         'type': 11,
#         'instruction': 'Head east',
#         'name': '-',
#         'way_points': [1655, 1656]},
#        {'distance': 0.027,
#         'duration': 9.6,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [1656, 1657]},
#        {'distance': 0.257,
#         'duration': 61.7,
#         'type': 0,
#         'instruction': 'Turn left onto Jalan Dukuh Sapen',
#         'name': 'Jalan Dukuh Sapen',
#         'way_points': [1657, 1667]},
#        {'distance': 0.856,
#         'duration': 205.3,
#         'type': 1,
#         'instruction': 'Turn right onto Jalan Dukuh Sapen',
#         'name': 'Jalan Dukuh Sapen',
#         'way_points': [1667, 1688]},
#        {'distance': 3.674,
#         'duration': 281.5,
#         'type': 0,
#         'instruction': 'Turn left onto Jalan Sapen Raya',
#         'name': 'Jalan Sapen Raya',
#         'way_points': [1688, 1774]},
#        {'distance': 1.632,
#         'duration': 124.0,
#         'type': 6,
#         'instruction': 'Continue straight onto Jalan Kauman',
#         'name': 'Jalan Kauman',
#         'way_points': [1774, 1811]},
#        {'distance': 3.237,
#         'duration': 246.5,
#         'type': 2,
#         'instruction': 'Turn sharp left onto Jalan Anyar Gondoriyo Wates',
#         'name': 'Jalan Anyar Gondoriyo Wates',
#         'way_points': [1811, 1870]},
#        {'distance': 2.254,
#         'duration': 101.4,
#         'type': 0,
#         'instruction': 'Turn left onto Jalan Jenderal Urip Sumoharjo, 1',
#         'name': 'Jalan Jenderal Urip Sumoharjo, 1',
#         'way_points': [1870, 1916]},
#        {'distance': 0.449,
#         'duration': 43.3,
#         'type': 12,
#         'instruction': 'Keep left onto 1',
#         'name': '1',
#         'way_points': [1916, 1923]},
#        {'distance': 3.067,
#         'duration': 205.2,
#         'type': 4,
#         'instruction': 'Turn slight left onto Jalan Raya Kaliwungu, 1',
#         'name': 'Jalan Raya Kaliwungu, 1',
#         'way_points': [1923, 2012]},
#        {'distance': 4.86,
#         'duration': 317.0,
#         'type': 0,
#         'instruction': 'Turn left onto Jalan Kyai Haji Ashari',
#         'name': 'Jalan Kyai Haji Ashari',
#         'way_points': [2012, 2121]},
#        {'distance': 1.984,
#         'duration': 240.7,
#         'type': 0,
#         'instruction': 'Turn left onto Jalan Kertomulyo',
#         'name': 'Jalan Kertomulyo',
#         'way_points': [2121, 2139]},
#        {'distance': 0.2,
#         'duration': 24.1,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [2139, 2141]},
#        {'distance': 0.028,
#         'duration': 6.8,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [2141, 2142]},
#        {'distance': 0.0,
#         'duration': 0.0,
#         'type': 10,
#         'instruction': 'Arrive at your destination, on the left',
#         'name': '-',
#         'way_points': [2142, 2142]}]},
#      {'distance': 8.097,
#       'duration': 721.0,
#       'steps': [{'distance': 0.028,
#         'duration': 6.8,
#         'type': 11,
#         'instruction': 'Head southwest',
#         'name': '-',
#         'way_points': [2142, 2143]},
#        {'distance': 0.2,
#         'duration': 24.1,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [2143, 2145]},
#        {'distance': 1.984,
#         'duration': 240.7,
#         'type': 0,
#         'instruction': 'Turn left onto Jalan Kertomulyo',
#         'name': 'Jalan Kertomulyo',
#         'way_points': [2145, 2163]},
#        {'distance': 0.747,
#         'duration': 61.5,
#         'type': 2,
#         'instruction': 'Turn sharp left',
#         'name': '-',
#         'way_points': [2163, 2182]},
#        {'distance': 2.086,
#         'duration': 127.3,
#         'type': 3,
#         'instruction': 'Turn sharp right',
#         'name': '-',
#         'way_points': [2182, 2206]},
#        {'distance': 2.467,
#         'duration': 148.0,
#         'type': 0,
#         'instruction': 'Turn left onto Jalan Sunan Ampel',
#         'name': 'Jalan Sunan Ampel',
#         'way_points': [2206, 2257]},
#        {'distance': 0.406,
#         'duration': 48.7,
#         'type': 12,
#         'instruction': 'Keep left',
#         'name': '-',
#         'way_points': [2257, 2264]},
#        {'distance': 0.177,
#         'duration': 63.9,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [2264, 2265]},
#        {'distance': 0.0,
#         'duration': 0.0,
#         'type': 10,
#         'instruction': 'Arrive at your destination, on the right',
#         'name': '-',
#         'way_points': [2265, 2265]}]},
#      {'distance': 0.863,
#       'duration': 129.3,
#       'steps': [{'distance': 0.177,
#         'duration': 63.9,
#         'type': 11,
#         'instruction': 'Head north',
#         'name': '-',
#         'way_points': [2265, 2266]},
#        {'distance': 0.406,
#         'duration': 48.7,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [2266, 2273]},
#        {'distance': 0.279,
#         'duration': 16.8,
#         'type': 2,
#         'instruction': 'Turn sharp left onto Jalan Sunan Ampel',
#         'name': 'Jalan Sunan Ampel',
#         'way_points': [2273, 2280]},
#        {'distance': 0.0,
#         'duration': 0.0,
#         'type': 10,
#         'instruction': 'Arrive at Jalan Sunan Ampel, on the right',
#         'name': '-',
#         'way_points': [2280, 2280]}]},
#      {'distance': 34.794,
#       'duration': 2400.1,
#       'steps': [{'distance': 2.329,
#         'duration': 158.7,
#         'type': 11,
#         'instruction': 'Head south on Jalan Sunan Ampel',
#         'name': 'Jalan Sunan Ampel',
#         'way_points': [2280, 2319]},
#        {'distance': 1.374,
#         'duration': 117.0,
#         'type': 6,
#         'instruction': 'Continue straight',
#         'name': '-',
#         'way_points': [2319, 2352]},
#        {'distance': 8.049,
#         'duration': 579.5,
#         'type': 12,
#         'instruction': 'Keep left',
#         'name': '-',
#         'way_points': [2352, 2568]},
#        {'distance': 0.275,
#         'duration': 19.8,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [2568, 2579]},
#        {'distance': 0.092,
#         'duration': 11.0,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [2579, 2581]},
#        {'distance': 0.059,
#         'duration': 10.5,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [2581, 2582]},
#        {'distance': 1.407,
#         'duration': 105.0,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [2582, 2607]},
#        {'distance': 0.098,
#         'duration': 11.7,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [2607, 2608]},
#        {'distance': 1.075,
#         'duration': 86.0,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [2608, 2628]},
#        {'distance': 2.999,
#         'duration': 179.9,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [2628, 2720]},
#        {'distance': 4.618,
#         'duration': 303.7,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [2720, 2844]},
#        {'distance': 9.335,
#         'duration': 572.6,
#         'type': 3,
#         'instruction': 'Turn sharp right',
#         'name': '-',
#         'way_points': [2844, 3078]},
#        {'distance': 1.392,
#         'duration': 110.2,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [3078, 3130]},
#        {'distance': 1.621,
#         'duration': 116.7,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [3130, 3188]},
#        {'distance': 0.073,
#         'duration': 17.6,
#         'type': 2,
#         'instruction': 'Turn sharp left',
#         'name': '-',
#         'way_points': [3188, 3194]},
#        {'distance': 0.0,
#         'duration': 0.0,
#         'type': 10,
#         'instruction': 'Arrive at your destination, on the right',
#         'name': '-',
#         'way_points': [3194, 3194]}]},
#      {'distance': 32.034,
#       'duration': 2053.5,
#       'steps': [{'distance': 0.073,
#         'duration': 17.6,
#         'type': 11,
#         'instruction': 'Head southeast',
#         'name': '-',
#         'way_points': [3194, 3200]},
#        {'distance': 1.621,
#         'duration': 116.7,
#         'type': 3,
#         'instruction': 'Turn sharp right',
#         'name': '-',
#         'way_points': [3200, 3258]},
#        {'distance': 1.392,
#         'duration': 110.2,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [3258, 3310]},
#        {'distance': 3.458,
#         'duration': 214.8,
#         'type': 1,
#         'instruction': 'Turn right onto Jalan Curug Sewu',
#         'name': 'Jalan Curug Sewu',
#         'way_points': [3310, 3362]},
#        {'distance': 2.261,
#         'duration': 159.6,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [3362, 3413]},
#        {'distance': 0.147,
#         'duration': 21.2,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [3413, 3424]},
#        {'distance': 0.319,
#         'duration': 31.5,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [3424, 3432]},
#        {'distance': 5.558,
#         'duration': 346.1,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [3432, 3577]},
#        {'distance': 13.39,
#         'duration': 831.2,
#         'type': 5,
#         'instruction': 'Turn slight right',
#         'name': '-',
#         'way_points': [3577, 4109]},
#        {'distance': 2.06,
#         'duration': 92.7,
#         'type': 2,
#         'instruction': 'Turn sharp left onto Jalan Utama, 1',
#         'name': 'Jalan Utama, 1',
#         'way_points': [4109, 4146]},
#        {'distance': 1.227,
#         'duration': 55.2,
#         'type': 6,
#         'instruction': 'Continue straight onto Jalan Raya Utama, 1',
#         'name': 'Jalan Raya Utama, 1',
#         'way_points': [4146, 4161]},
#        {'distance': 0.526,
#         'duration': 56.7,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [4161, 4172]},
#        {'distance': 0.0,
#         'duration': 0.0,
#         'type': 10,
#         'instruction': 'Arrive at your destination, on the right',
#         'name': '-',
#         'way_points': [4172, 4172]}]},
#      {'distance': 24.728,
#       'duration': 1292.1,
#       'steps': [{'distance': 0.516,
#         'duration': 53.1,
#         'type': 11,
#         'instruction': 'Head south on Gringsing',
#         'name': 'Gringsing',
#         'way_points': [4172, 4182]},
#        {'distance': 15.747,
#         'duration': 708.5,
#         'type': 0,
#         'instruction': 'Turn left onto Jalan Raya Batang - Weleri, 1',
#         'name': 'Jalan Raya Batang - Weleri, 1',
#         'way_points': [4182, 4440]},
#        {'distance': 0.382,
#         'duration': 24.2,
#         'type': 13,
#         'instruction': 'Keep right',
#         'name': '-',
#         'way_points': [4440, 4452]},
#        {'distance': 0.083,
#         'duration': 3.7,
#         'type': 12,
#         'instruction': 'Keep left',
#         'name': '-',
#         'way_points': [4452, 4455]},
#        {'distance': 1.926,
#         'duration': 86.7,
#         'type': 2,
#         'instruction': 'Turn sharp left onto Jalan Tentara Pelajar',
#         'name': 'Jalan Tentara Pelajar',
#         'way_points': [4455, 4480]},
#        {'distance': 0.101,
#         'duration': 4.6,
#         'type': 7,
#         'instruction': 'Enter the roundabout and take the 2nd exit',
#         'name': '-',
#         'exit_number': 2,
#         'way_points': [4480, 4486]},
#        {'distance': 2.331,
#         'duration': 104.9,
#         'type': 6,
#         'instruction': 'Continue straight onto Jalan Tentara Pelajar',
#         'name': 'Jalan Tentara Pelajar',
#         'way_points': [4486, 4524]},
#        {'distance': 2.205,
#         'duration': 143.0,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [4524, 4598]},
#        {'distance': 1.053,
#         'duration': 71.2,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [4598, 4632]},
#        {'distance': 0.384,
#         'duration': 92.1,
#         'type': 3,
#         'instruction': 'Turn sharp right',
#         'name': '-',
#         'way_points': [4632, 4646]},
#        {'distance': 0.0,
#         'duration': 0.0,
#         'type': 10,
#         'instruction': 'Arrive at your destination, on the left',
#         'name': '-',
#         'way_points': [4646, 4646]}]},
#      {'distance': 12.815,
#       'duration': 1124.2,
#       'steps': [{'distance': 0.384,
#         'duration': 92.1,
#         'type': 11,
#         'instruction': 'Head southwest',
#         'name': '-',
#         'way_points': [4646, 4660]},
#        {'distance': 4.734,
#         'duration': 290.6,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [4660, 4765]},
#        {'distance': 0.343,
#         'duration': 38.2,
#         'type': 6,
#         'instruction': 'Continue straight',
#         'name': '-',
#         'way_points': [4765, 4773]},
#        {'distance': 0.557,
#         'duration': 44.6,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [4773, 4795]},
#        {'distance': 4.999,
#         'duration': 394.0,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [4795, 4855]},
#        {'distance': 1.456,
#         'duration': 182.7,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [4855, 4878]},
#        {'distance': 0.342,
#         'duration': 82.1,
#         'type': 2,
#         'instruction': 'Turn sharp left',
#         'name': '-',
#         'way_points': [4878, 4889]},
#        {'distance': 0.0,
#         'duration': 0.0,
#         'type': 10,
#         'instruction': 'Arrive at your destination, on the left',
#         'name': '-',
#         'way_points': [4889, 4889]}]},
#      {'distance': 12.111,
#       'duration': 1031.8,
#       'steps': [{'distance': 0.342,
#         'duration': 82.1,
#         'type': 11,
#         'instruction': 'Head west',
#         'name': '-',
#         'way_points': [4889, 4900]},
#        {'distance': 1.456,
#         'duration': 182.7,
#         'type': 3,
#         'instruction': 'Turn sharp right',
#         'name': '-',
#         'way_points': [4900, 4923]},
#        {'distance': 4.999,
#         'duration': 394.0,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [4923, 4983]},
#        {'distance': 0.557,
#         'duration': 44.6,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [4983, 5005]},
#        {'distance': 0.343,
#         'duration': 38.2,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [5005, 5013]},
#        {'distance': 4.308,
#         'duration': 265.0,
#         'type': 6,
#         'instruction': 'Continue straight',
#         'name': '-',
#         'way_points': [5013, 5108]},
#        {'distance': 0.105,
#         'duration': 25.2,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [5108, 5113]},
#        {'distance': 0.0,
#         'duration': 0.0,
#         'type': 10,
#         'instruction': 'Arrive at your destination, on the right',
#         'name': '-',
#         'way_points': [5113, 5113]}]},
#      {'distance': 14.973,
#       'duration': 2121.5,
#       'steps': [{'distance': 0.105,
#         'duration': 25.2,
#         'type': 11,
#         'instruction': 'Head west',
#         'name': '-',
#         'way_points': [5113, 5118]},
#        {'distance': 4.308,
#         'duration': 265.0,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [5118, 5213]},
#        {'distance': 0.343,
#         'duration': 38.2,
#         'type': 6,
#         'instruction': 'Continue straight',
#         'name': '-',
#         'way_points': [5213, 5221]},
#        {'distance': 0.557,
#         'duration': 44.6,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [5221, 5243]},
#        {'distance': 1.808,
#         'duration': 133.6,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [5243, 5267]},
#        {'distance': 1.305,
#         'duration': 105.1,
#         'type': 0,
#         'instruction': 'Turn left onto Sedayu - Sojomerto',
#         'name': 'Sedayu - Sojomerto',
#         'way_points': [5267, 5287]},
#        {'distance': 0.401,
#         'duration': 28.9,
#         'type': 1,
#         'instruction': 'Turn right onto Sedayu - Sojomerto',
#         'name': 'Sedayu - Sojomerto',
#         'way_points': [5287, 5296]},
#        {'distance': 0.054,
#         'duration': 13.0,
#         'type': 3,
#         'instruction': 'Turn sharp right',
#         'name': '-',
#         'way_points': [5296, 5299]},
#        {'distance': 0.164,
#         'duration': 39.3,
#         'type': 2,
#         'instruction': 'Turn sharp left',
#         'name': '-',
#         'way_points': [5299, 5301]},
#        {'distance': 0.229,
#         'duration': 55.0,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [5301, 5305]},
#        {'distance': 0.092,
#         'duration': 22.1,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [5305, 5309]},
#        {'distance': 0.525,
#         'duration': 125.9,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [5309, 5317]},
#        {'distance': 0.94,
#         'duration': 225.5,
#         'type': 12,
#         'instruction': 'Keep left',
#         'name': '-',
#         'way_points': [5317, 5337]},
#        {'distance': 2.402,
#         'duration': 576.5,
#         'type': 4,
#         'instruction': 'Turn slight left',
#         'name': '-',
#         'way_points': [5337, 5390]},
#        {'distance': 0.14,
#         'duration': 33.7,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [5390, 5395]},
#        {'distance': 0.025,
#         'duration': 6.0,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [5395, 5396]},
#        {'distance': 0.879,
#         'duration': 211.1,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [5396, 5423]},
#        {'distance': 0.695,
#         'duration': 173.0,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [5423, 5466]},
#        {'distance': 0.0,
#         'duration': 0.0,
#         'type': 10,
#         'instruction': 'Arrive at your destination, on the right',
#         'name': '-',
#         'way_points': [5466, 5466]}]},
#      {'distance': 28.996,
#       'duration': 2620.3,
#       'steps': [{'distance': 0.695,
#         'duration': 173.0,
#         'type': 11,
#         'instruction': 'Head east',
#         'name': '-',
#         'way_points': [5466, 5509]},
#        {'distance': 0.879,
#         'duration': 211.1,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [5509, 5536]},
#        {'distance': 0.025,
#         'duration': 6.0,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [5536, 5537]},
#        {'distance': 0.14,
#         'duration': 33.6,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [5537, 5541]},
#        {'distance': 0.457,
#         'duration': 109.7,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [5541, 5547]},
#        {'distance': 0.181,
#         'duration': 43.5,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [5547, 5551]},
#        {'distance': 0.039,
#         'duration': 9.4,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [5551, 5552]},
#        {'distance': 1.823,
#         'duration': 437.4,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [5552, 5573]},
#        {'distance': 0.407,
#         'duration': 48.8,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [5573, 5582]},
#        {'distance': 0.057,
#         'duration': 6.8,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [5582, 5584]},
#        {'distance': 0.922,
#         'duration': 110.6,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [5584, 5601]},
#        {'distance': 0.301,
#         'duration': 36.1,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [5601, 5608]},
#        {'distance': 0.106,
#         'duration': 12.7,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [5608, 5610]},
#        {'distance': 1.101,
#         'duration': 132.1,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [5610, 5644]},
#        {'distance': 0.267,
#         'duration': 32.0,
#         'type': 13,
#         'instruction': 'Keep right',
#         'name': '-',
#         'way_points': [5644, 5651]},
#        {'distance': 0.025,
#         'duration': 3.0,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [5651, 5652]},
#        {'distance': 0.323,
#         'duration': 33.8,
#         'type': 12,
#         'instruction': 'Keep left',
#         'name': '-',
#         'way_points': [5652, 5665]},
#        {'distance': 0.206,
#         'duration': 16.5,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [5665, 5667]},
#        {'distance': 0.133,
#         'duration': 14.3,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [5667, 5671]},
#        {'distance': 0.376,
#         'duration': 30.1,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [5671, 5683]},
#        {'distance': 0.447,
#         'duration': 35.7,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [5683, 5692]},
#        {'distance': 0.177,
#         'duration': 14.2,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [5692, 5695]},
#        {'distance': 1.447,
#         'duration': 122.9,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [5695, 5717]},
#        {'distance': 12.14,
#         'duration': 546.2,
#         'type': 3,
#         'instruction': 'Turn sharp right onto Jalan Raya Motong Sari, 1',
#         'name': 'Jalan Raya Motong Sari, 1',
#         'way_points': [5717, 5909]},
#        {'distance': 0.382,
#         'duration': 24.2,
#         'type': 13,
#         'instruction': 'Keep right',
#         'name': '-',
#         'way_points': [5909, 5921]},
#        {'distance': 0.083,
#         'duration': 3.7,
#         'type': 12,
#         'instruction': 'Keep left',
#         'name': '-',
#         'way_points': [5921, 5924]},
#        {'distance': 1.926,
#         'duration': 86.7,
#         'type': 2,
#         'instruction': 'Turn sharp left onto Jalan Tentara Pelajar',
#         'name': 'Jalan Tentara Pelajar',
#         'way_points': [5924, 5949]},
#        {'distance': 0.101,
#         'duration': 4.6,
#         'type': 7,
#         'instruction': 'Enter the roundabout and take the 2nd exit',
#         'name': '-',
#         'exit_number': 2,
#         'way_points': [5949, 5955]},
#        {'distance': 2.331,
#         'duration': 104.9,
#         'type': 6,
#         'instruction': 'Continue straight onto Jalan Tentara Pelajar',
#         'name': 'Jalan Tentara Pelajar',
#         'way_points': [5955, 5993]},
#        {'distance': 1.037,
#         'duration': 73.0,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [5993, 6030]},
#        {'distance': 0.062,
#         'duration': 7.5,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [6030, 6032]},
#        {'distance': 0.015,
#         'duration': 3.6,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [6032, 6035]},
#        {'distance': 0.386,
#         'duration': 92.7,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [6035, 6038]},
#        {'distance': 0.0,
#         'duration': 0.0,
#         'type': 10,
#         'instruction': 'Arrive at your destination, on the right',
#         'name': '-',
#         'way_points': [6038, 6038]}]},
#      {'distance': 24.385,
#       'duration': 2122.5,
#       'steps': [{'distance': 0.386,
#         'duration': 92.7,
#         'type': 11,
#         'instruction': 'Head west',
#         'name': '-',
#         'way_points': [6038, 6041]},
#        {'distance': 0.015,
#         'duration': 3.6,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [6041, 6044]},
#        {'distance': 0.062,
#         'duration': 7.5,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [6044, 6046]},
#        {'distance': 1.037,
#         'duration': 73.0,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [6046, 6083]},
#        {'distance': 0.919,
#         'duration': 41.3,
#         'type': 1,
#         'instruction': 'Turn right onto Jalan Tentara Pelajar',
#         'name': 'Jalan Tentara Pelajar',
#         'way_points': [6083, 6096]},
#        {'distance': 3.252,
#         'duration': 146.3,
#         'type': 1,
#         'instruction': 'Turn right onto Jalan Raya Kendal-Semarang, 1',
#         'name': 'Jalan Raya Kendal-Semarang, 1',
#         'way_points': [6096, 6154]},
#        {'distance': 0.114,
#         'duration': 11.7,
#         'type': 13,
#         'instruction': 'Keep right',
#         'name': '-',
#         'way_points': [6154, 6159]},
#        {'distance': 0.126,
#         'duration': 15.1,
#         'type': 6,
#         'instruction': 'Continue straight onto 1',
#         'name': '1',
#         'way_points': [6159, 6164]},
#        {'distance': 0.925,
#         'duration': 73.7,
#         'type': 4,
#         'instruction': 'Turn slight left onto Jalan Raya Kaliwungu, 1',
#         'name': 'Jalan Raya Kaliwungu, 1',
#         'way_points': [6164, 6184]},
#        {'distance': 1.115,
#         'duration': 92.0,
#         'type': 1,
#         'instruction': 'Turn right onto Jalan Sekopek',
#         'name': 'Jalan Sekopek',
#         'way_points': [6184, 6221]},
#        {'distance': 0.233,
#         'duration': 15.2,
#         'type': 4,
#         'instruction': 'Turn slight left onto Jalan Kyai Haji Ashari',
#         'name': 'Jalan Kyai Haji Ashari',
#         'way_points': [6221, 6228]},
#        {'distance': 12.26,
#         'duration': 779.6,
#         'type': 1,
#         'instruction': 'Turn right onto Jalan Raya Kaliwungu-Boja',
#         'name': 'Jalan Raya Kaliwungu-Boja',
#         'way_points': [6228, 6501]},
#        {'distance': 0.721,
#         'duration': 86.5,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [6501, 6514]},
#        {'distance': 0.812,
#         'duration': 102.1,
#         'type': 12,
#         'instruction': 'Keep left',
#         'name': '-',
#         'way_points': [6514, 6530]},
#        {'distance': 0.082,
#         'duration': 19.8,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [6530, 6533]},
#        {'distance': 0.148,
#         'duration': 35.5,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [6533, 6539]},
#        {'distance': 0.236,
#         'duration': 56.6,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [6539, 6545]},
#        {'distance': 0.424,
#         'duration': 101.8,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [6545, 6557]},
#        {'distance': 1.032,
#         'duration': 252.0,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [6557, 6578]},
#        {'distance': 0.375,
#         'duration': 90.0,
#         'type': 6,
#         'instruction': 'Continue straight',
#         'name': '-',
#         'way_points': [6578, 6592]},
#        {'distance': 0.083,
#         'duration': 19.8,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [6592, 6595]},
#        {'distance': 0.029,
#         'duration': 6.9,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [6595, 6597]},
#        {'distance': 0.0,
#         'duration': 0.0,
#         'type': 10,
#         'instruction': 'Arrive at your destination, on the right',
#         'name': '-',
#         'way_points': [6597, 6597]}]},
#      {'distance': 49.602,
#       'duration': 3395.8,
#       'steps': [{'distance': 0.029,
#         'duration': 6.9,
#         'type': 11,
#         'instruction': 'Head east',
#         'name': '-',
#         'way_points': [6597, 6599]},
#        {'distance': 0.083,
#         'duration': 19.8,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [6599, 6602]},
#        {'distance': 0.375,
#         'duration': 90.0,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [6602, 6616]},
#        {'distance': 1.032,
#         'duration': 252.0,
#         'type': 6,
#         'instruction': 'Continue straight',
#         'name': '-',
#         'way_points': [6616, 6637]},
#        {'distance': 0.424,
#         'duration': 101.8,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [6637, 6649]},
#        {'distance': 0.236,
#         'duration': 56.6,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [6649, 6655]},
#        {'distance': 0.148,
#         'duration': 35.5,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [6655, 6661]},
#        {'distance': 0.082,
#         'duration': 19.8,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [6661, 6664]},
#        {'distance': 1.533,
#         'duration': 188.5,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [6664, 6693]},
#        {'distance': 12.26,
#         'duration': 779.6,
#         'type': 1,
#         'instruction': 'Turn right onto Jalan Raya Kaliwungu-Boja',
#         'name': 'Jalan Raya Kaliwungu-Boja',
#         'way_points': [6693, 6966]},
#        {'distance': 0.233,
#         'duration': 15.2,
#         'type': 0,
#         'instruction': 'Turn left onto Jalan Kyai Haji Ashari',
#         'name': 'Jalan Kyai Haji Ashari',
#         'way_points': [6966, 6973]},
#        {'distance': 1.115,
#         'duration': 92.0,
#         'type': 13,
#         'instruction': 'Keep right',
#         'name': '-',
#         'way_points': [6973, 7010]},
#        {'distance': 0.983,
#         'duration': 84.1,
#         'type': 0,
#         'instruction': 'Turn left onto Jalan Raya Kaliwungu, 1',
#         'name': 'Jalan Raya Kaliwungu, 1',
#         'way_points': [7010, 7033]},
#        {'distance': 3.423,
#         'duration': 161.6,
#         'type': 12,
#         'instruction': 'Keep left',
#         'name': '-',
#         'way_points': [7033, 7100]},
#        {'distance': 3.316,
#         'duration': 149.2,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [7100, 7152]},
#        {'distance': 11.838,
#         'duration': 532.7,
#         'type': 7,
#         'instruction': 'Enter the roundabout and take the 1st exit onto Jalan Tentara Pelajar',
#         'name': 'Jalan Tentara Pelajar',
#         'exit_number': 1,
#         'way_points': [7152, 7323]},
#        {'distance': 0.274,
#         'duration': 12.3,
#         'type': 12,
#         'instruction': 'Keep left onto Jalan Utama, 1',
#         'name': 'Jalan Utama, 1',
#         'way_points': [7323, 7329]},
#        {'distance': 4.302,
#         'duration': 193.6,
#         'type': 6,
#         'instruction': 'Continue straight onto Jalan Raya Motong Sari, 1',
#         'name': 'Jalan Raya Motong Sari, 1',
#         'way_points': [7329, 7424]},
#        {'distance': 2.128,
#         'duration': 95.7,
#         'type': 6,
#         'instruction': 'Continue straight onto Jalan Raya Utama, 1',
#         'name': 'Jalan Raya Utama, 1',
#         'way_points': [7424, 7452]},
#        {'distance': 2.074,
#         'duration': 93.3,
#         'type': 1,
#         'instruction': 'Turn right onto 1',
#         'name': '1',
#         'way_points': [7452, 7488]},
#        {'distance': 2.862,
#         'duration': 211.0,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [7488, 7531]},
#        {'distance': 0.221,
#         'duration': 52.9,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [7531, 7536]},
#        {'distance': 0.053,
#         'duration': 12.7,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [7536, 7537]},
#        {'distance': 0.175,
#         'duration': 41.9,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [7537, 7540]},
#        {'distance': 0.404,
#         'duration': 97.0,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [7540, 7545]},
#        {'distance': 0.0,
#         'duration': 0.0,
#         'type': 10,
#         'instruction': 'Arrive at your destination, on the right',
#         'name': '-',
#         'way_points': [7545, 7545]}]},
#      {'distance': 44.576,
#       'duration': 2601.1,
#       'steps': [{'distance': 0.404,
#         'duration': 97.0,
#         'type': 11,
#         'instruction': 'Head south',
#         'name': '-',
#         'way_points': [7545, 7550]},
#        {'distance': 0.175,
#         'duration': 41.9,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [7550, 7553]},
#        {'distance': 0.053,
#         'duration': 12.7,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [7553, 7554]},
#        {'distance': 0.221,
#         'duration': 52.9,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [7554, 7559]},
#        {'distance': 2.862,
#         'duration': 211.0,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [7559, 7602]},
#        {'distance': 18.708,
#         'duration': 849.2,
#         'type': 0,
#         'instruction': 'Turn left onto Jalan Raya Batang - Weleri, 1',
#         'name': 'Jalan Raya Batang - Weleri, 1',
#         'way_points': [7602, 7903]},
#        {'distance': 0.382,
#         'duration': 24.2,
#         'type': 13,
#         'instruction': 'Keep right',
#         'name': '-',
#         'way_points': [7903, 7915]},
#        {'distance': 0.083,
#         'duration': 3.7,
#         'type': 12,
#         'instruction': 'Keep left',
#         'name': '-',
#         'way_points': [7915, 7918]},
#        {'distance': 1.926,
#         'duration': 86.7,
#         'type': 2,
#         'instruction': 'Turn sharp left onto Jalan Tentara Pelajar',
#         'name': 'Jalan Tentara Pelajar',
#         'way_points': [7918, 7943]},
#        {'distance': 0.101,
#         'duration': 4.6,
#         'type': 7,
#         'instruction': 'Enter the roundabout and take the 2nd exit',
#         'name': '-',
#         'exit_number': 2,
#         'way_points': [7943, 7949]},
#        {'distance': 3.25,
#         'duration': 146.2,
#         'type': 6,
#         'instruction': 'Continue straight onto Jalan Tentara Pelajar',
#         'name': 'Jalan Tentara Pelajar',
#         'way_points': [7949, 8000]},
#        {'distance': 3.252,
#         'duration': 146.3,
#         'type': 1,
#         'instruction': 'Turn right onto Jalan Raya Kendal-Semarang, 1',
#         'name': 'Jalan Raya Kendal-Semarang, 1',
#         'way_points': [8000, 8058]},
#        {'distance': 0.114,
#         'duration': 11.7,
#         'type': 13,
#         'instruction': 'Keep right',
#         'name': '-',
#         'way_points': [8058, 8063]},
#        {'distance': 0.126,
#         'duration': 15.1,
#         'type': 6,
#         'instruction': 'Continue straight onto 1',
#         'name': '1',
#         'way_points': [8063, 8068]},
#        {'distance': 0.925,
#         'duration': 73.7,
#         'type': 4,
#         'instruction': 'Turn slight left onto Jalan Raya Kaliwungu, 1',
#         'name': 'Jalan Raya Kaliwungu, 1',
#         'way_points': [8068, 8088]},
#        {'distance': 1.115,
#         'duration': 92.0,
#         'type': 1,
#         'instruction': 'Turn right onto Jalan Sekopek',
#         'name': 'Jalan Sekopek',
#         'way_points': [8088, 8125]},
#        {'distance': 0.233,
#         'duration': 15.2,
#         'type': 4,
#         'instruction': 'Turn slight left onto Jalan Kyai Haji Ashari',
#         'name': 'Jalan Kyai Haji Ashari',
#         'way_points': [8125, 8132]},
#        {'distance': 5.758,
#         'duration': 357.2,
#         'type': 1,
#         'instruction': 'Turn right onto Jalan Raya Kaliwungu-Boja',
#         'name': 'Jalan Raya Kaliwungu-Boja',
#         'way_points': [8132, 8270]},
#        {'distance': 4.89,
#         'duration': 359.6,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [8270, 8343]},
#        {'distance': 0.0,
#         'duration': 0.0,
#         'type': 10,
#         'instruction': 'Arrive at your destination, on the right',
#         'name': '-',
#         'way_points': [8343, 8343]}]},
#      {'distance': 29.574,
#       'duration': 1712.5,
#       'steps': [{'distance': 4.89,
#         'duration': 359.6,
#         'type': 11,
#         'instruction': 'Head east',
#         'name': '-',
#         'way_points': [8343, 8416]},
#        {'distance': 5.758,
#         'duration': 357.2,
#         'type': 0,
#         'instruction': 'Turn left onto Jalan Raya Kaliwungu-Boja',
#         'name': 'Jalan Raya Kaliwungu-Boja',
#         'way_points': [8416, 8554]},
#        {'distance': 0.233,
#         'duration': 15.2,
#         'type': 0,
#         'instruction': 'Turn left onto Jalan Kyai Haji Ashari',
#         'name': 'Jalan Kyai Haji Ashari',
#         'way_points': [8554, 8561]},
#        {'distance': 1.115,
#         'duration': 92.0,
#         'type': 13,
#         'instruction': 'Keep right',
#         'name': '-',
#         'way_points': [8561, 8598]},
#        {'distance': 0.983,
#         'duration': 84.1,
#         'type': 0,
#         'instruction': 'Turn left onto Jalan Raya Kaliwungu, 1',
#         'name': 'Jalan Raya Kaliwungu, 1',
#         'way_points': [8598, 8621]},
#        {'distance': 3.423,
#         'duration': 161.6,
#         'type': 12,
#         'instruction': 'Keep left',
#         'name': '-',
#         'way_points': [8621, 8688]},
#        {'distance': 3.316,
#         'duration': 149.2,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [8688, 8740]},
#        {'distance': 8.188,
#         'duration': 368.4,
#         'type': 7,
#         'instruction': 'Enter the roundabout and take the 1st exit onto Jalan Tentara Pelajar',
#         'name': 'Jalan Tentara Pelajar',
#         'exit_number': 1,
#         'way_points': [8740, 8863]},
#        {'distance': 1.351,
#         'duration': 63.5,
#         'type': 6,
#         'instruction': 'Continue straight onto Jalan Raya Batang-Kendal, 1',
#         'name': 'Jalan Raya Batang-Kendal, 1',
#         'way_points': [8863, 8884]},
#        {'distance': 0.318,
#         'duration': 61.6,
#         'type': 0,
#         'instruction': 'Turn left',
# ...
#         'name': 'Jalan Tegalsari',
#         'way_points': [76870, 76875]},
#        {'distance': 1.013,
#         'duration': 243.2,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [76875, 76892]},
#        {'distance': 0.076,
#         'duration': 27.3,
#         'type': 1,
#         'instruction': 'Turn right onto Jalan Kuripan',
#         'name': 'Jalan Kuripan',
#         'way_points': [76892, 76894]},
#        {'distance': 0.129,
#         'duration': 30.9,
#         'type': 0,
#         'instruction': 'Turn left onto Jalan Kuripan',
#         'name': 'Jalan Kuripan',
#         'way_points': [76894, 76898]},
#        {'distance': 0.86,
#         'duration': 61.9,
#         'type': 0,
#         'instruction': 'Turn left onto Jalan Raya Kuripan',
#         'name': 'Jalan Raya Kuripan',
#         'way_points': [76898, 76922]},
#        {'distance': 3.674,
#         'duration': 281.5,
#         'type': 1,
#         'instruction': 'Turn right onto Jalan Sapen Raya',
#         'name': 'Jalan Sapen Raya',
#         'way_points': [76922, 77008]},
#        {'distance': 1.632,
#         'duration': 124.0,
#         'type': 6,
#         'instruction': 'Continue straight onto Jalan Kauman',
#         'name': 'Jalan Kauman',
#         'way_points': [77008, 77045]},
#        {'distance': 3.237,
#         'duration': 246.5,
#         'type': 2,
#         'instruction': 'Turn sharp left onto Jalan Anyar Gondoriyo Wates',
#         'name': 'Jalan Anyar Gondoriyo Wates',
#         'way_points': [77045, 77104]},
#        {'distance': 8.361,
#         'duration': 376.2,
#         'type': 0,
#         'instruction': 'Turn left onto Jalan Jenderal Urip Sumoharjo, 1',
#         'name': 'Jalan Jenderal Urip Sumoharjo, 1',
#         'way_points': [77104, 77225]},
#        {'distance': 4.046,
#         'duration': 492.7,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [77225, 77268]},
#        {'distance': 1.042,
#         'duration': 128.9,
#         'type': 6,
#         'instruction': 'Continue straight onto Jalan Saptarengga',
#         'name': 'Jalan Saptarengga',
#         'way_points': [77268, 77272]},
#        {'distance': 0.328,
#         'duration': 59.0,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [77272, 77274]},
#        {'distance': 0.0,
#         'duration': 0.0,
#         'type': 10,
#         'instruction': 'Arrive at your destination, on the right',
#         'name': '-',
#         'way_points': [77274, 77274]}]},
#      {'distance': 17.427,
#       'duration': 1259.2,
#       'steps': [{'distance': 0.328,
#         'duration': 59.0,
#         'type': 11,
#         'instruction': 'Head north',
#         'name': '-',
#         'way_points': [77274, 77276]},
#        {'distance': 2.942,
#         'duration': 356.7,
#         'type': 0,
#         'instruction': 'Turn left onto Jalan Saptarengga',
#         'name': 'Jalan Saptarengga',
#         'way_points': [77276, 77312]},
#        {'distance': 0.046,
#         'duration': 12.6,
#         'type': 13,
#         'instruction': 'Keep right',
#         'name': '-',
#         'way_points': [77312, 77314]},
#        {'distance': 5.257,
#         'duration': 236.5,
#         'type': 1,
#         'instruction': 'Turn right onto Jalan Lingkar Luar Kaliwungu, 1',
#         'name': 'Jalan Lingkar Luar Kaliwungu, 1',
#         'way_points': [77314, 77403]},
#        {'distance': 0.911,
#         'duration': 41.0,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [77403, 77416]},
#        {'distance': 2.205,
#         'duration': 143.0,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [77416, 77490]},
#        {'distance': 5.219,
#         'duration': 321.1,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [77490, 77622]},
#        {'distance': 0.519,
#         'duration': 89.2,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [77622, 77627]},
#        {'distance': 0.0,
#         'duration': 0.0,
#         'type': 10,
#         'instruction': 'Arrive at your destination, on the right',
#         'name': '-',
#         'way_points': [77627, 77627]}]}],
#     'bbox': [110.011444, -7.117238, 110.394297, -6.864065],
#     'geometry': 'zrni@qjj_TdFtDbAd@xNdDLBPDH{@|AoN@MZuCv@}GXqArAcGJuBe@aBE]AqAR{AHUj@oCT}A@]I[MUWO}Bg@y@OgB]iCm@UIIKM]Ei@As@Qk@o@oAc@g@u@q@SUMWKYMo@e@yFGiDNqB^mCHcAFULuA@cAAo@?qB`@kDFw@AUI[c@mAWg@[e@e@y@Oe@_@wA?WBg@TmBDk@Ae@Ea@IUOU_@Ma@Ke@G_BMe@Ca@?kA@g@@i@Fa@DkAL{@@cCIc@EwAWo@O}A_@yA_@cAa@UO_Aa@mAo@QQQYkBsFMS@YKu@CiAUeCCk@Aw@Gq@Kc@[cAKk@?QCWGuAC_@MeBGc@QwAOyAMq@WwBI_C]iBIs@Su@Wg@We@[e@SC]Ua@a@IEMQaAm@YKiBi@QM_@s@gAmBEO@IJUDIo@[iBmAuAgA[_@U][q@MWa@aAs@}@Yi@a@mAi@{Aq@}BQi@OWWYYWmAo@iBgAWMe@Mq@KWIe@W_@[SMWI[E[?g@@c@Fk@Hi@DgB@[CYEqA_@CAMCCAo@S[EaBCq@KcAUaBq@aBq@s@Ya@Oa@I_@Gu@Cw@GaAQMEa@Mi@e@_AmAYSUMm@I}@I{Ba@w@Yw@_@QISA[Aw@Ns@R]FY@WBqAA`@iD@A?M@QR}CZ_DfCmXBc@@{@QwAAa@QeAEOPG|EgBb@SfB_Af@[TQt@o@z@u@dAqBj@eATc@FKNYtA{C`DsG^w@bBgDBEDIRc@@EnAwCbA_Cf@mA`@aAx@mBxBcG@CL]v@eCn@iB~CgI^cAZy@FOVu@Rm@bA_DNg@j@eBh@oBL]@CBGnBcFxBaF|@yBnDqHl@qABEDMj@yA~AwEPg@HWl@}ANe@p@_BF]Lc@Dg@?a@Ca@Ke@O_@k@_AmB}A_MsIkIaGiD_C}CoBoC_BaMcH{JmFkFqCg@a@[WY_@u@yAMa@G]M{@CU?k@HoAf@sCbAwEdB_IvBsHPk@fAmDp@eBhAaClAiBnAaB~G{Ih@s@r@cAh@{@pEwHlAyB@CJQp@mAnA{BpEwHpGeL~@eBd@iA\\iAnAoFPs@pD}OVgAh@wBlBiIfAwEXkAT}@Pq@hBoHbC{HrAiEj@eBj@uA\\g@b@a@`Am@`@QbDeAbA]lIoCpH_Cz@QZGx@ExAAtAJ~A\\dCz@nAb@~@ZnMlEhDjA\\Jd@Hb@@b@Ej@MbA[TO^[\\i@|CeLZ{AZiATuAJm@DWl@cFLkATeCPuAD_@Py@L]lFiKDKJOFKd@aA^s@Tg@FKdAmBXi@p@uAf@eAVo@Xo@z@wCBIR{@HYdAyE@CT}@p@oCFU\\yBHc@TyB@_@JwC?OAaAGeEEgAIcBSwBQsAIoAM}AO}BSaDOmCGgAGs@McCAGCg@Ck@SkCC_ACw@?SKuFYoJAu@@}@Hk@Pu@Ri@Re@Zg@x@w@NTs@n@g@t@Wp@]tAEx@?l@JhCFzABpApC@x@DR?dAIj@?vAJtBXl@@`DG`BAz@D~Ad@t@Nz@DB_ABIFAhBJHD?nCEJDK?oCIEiBKG@CHC~@{@Eu@O_Be@{@EaB@aDFm@AuBYwAKk@?eAHS?y@EqCA@VBjAFxEBbA@NHdBJzADl@?L@j@RtDR|D`@bGBXVbDNhBV~BLtBBd@?^DhB@dCKxDKrAKlAi@tCq@|CCHS~@ADCLi@tBk@zB_@xAc@tAe@pAe@dAcAvBU`@qBtDm@nAS^IN?@KPS`@aBpDaBxFMd@k@pBK\\Ml@Mr@CPAJi@dFIj@EXS`Ak@vC_@tAU~@_AvDeApDKRSXYV]Tw@Z_@JSBg@Bg@Ak@Gc@MqDmAaMgEcIoCw@OsAMwABy@DWDwA\\uGpBqGxBcF|AaBl@}@l@c@`@ILYj@]x@{@rC}@tCcApCu@bC_@lAyAhGCHOn@AHQp@qEpRsCxLq@xCo@fC_BhHQn@e@dAoA`CsGlLqDnGkB~Ck@dAQV_HpLm@~@s@~@i@t@gBxB}F|HiAjB{@dB}@~Bm@jB[dAiCpImBlIyAtGKl@I`B?h@Df@Hl@J`@L\\fAfBX\\d@\\hRxJhHbExC`BnC`BnFxDlAv@|F`EnAdAfAn@lEzCvAhA`EvCd@h@PXN`@H\\FX@V?p@C`@GRIT_@bAWr@Wp@CF]~@A@e@nAmAdDcAfCGNKPs@~A{@fBi@dAuA~Cc@`AMXMXQ`@sA~Ce@fAUp@m@|AM^Qn@u@fC_@hAaAvC]bAwArDaBxEe@lAO`@q@hBw@dCC?O^aBtEqA|CcCdGCFsAtCUh@EDGNe@z@g@jAq@tAuF`L[p@aAlBm@lA]`@o@r@e@`@q@d@}A~@a@Pm@Z{Aj@}An@i@RBl@C\\@`@PvAAz@Cb@gClX[~CS|CAP?LA@a@hDG`ACVIbC?n@MnAkAfI_@jDAd@G`@o@pB[|@i@tBK`@a@`Co@rCEJm@hCgAfFG`@CL_AnFOx@Ed@@lB@PDbA@jCCzA[~Ak@bDg@lCW`B}BjMq@|Cw@~CCFABSbAQbC?N@R@VPzBn@rKh@bID`AEnAGl@K|@SpBQ~AQxBQlE[bJKvD@DC\\YfK?^\\nR?b@@n@APCHERI\\Mr@QvBAtAGxAKl@Qj@]x@_@Zs@p@eAb@sE`A{@`@m@r@Mb@Ch@Et@MfCc@zC[lCERcAfFu@nDWfA_@xAGVsA`Ek@zA_@`AyH`QQf@EHKh@@f@\\bHNxABVNr@b@|@Xd@z@l@~@^pFxAxFdB|CdAv@Zl@VvC`ALDzAd@zA`@zA^^JlDp@dBTjCd@t@RhA^b@Rj@`@nDtDx@lAVb@b@vAJv@d@xFXjCHd@LnAJv@Db@BRN|AVjCPtBTnCT|CHr@BNr@lD^rBJp@j@rCdBrJ|@pE~AnHt@xCx@nCBHJXbA`DZfAPv@vAjHj@hB~@|BfGpMlFdKlFdK`DdG|DzH~@rBRb@l@vA^r@n@jAdD`FjCtDrDrE~@jAzAbBbAhAh@p@jC~Cp@|@V^j@|@d@dANl@HXVvBTlBHt@f@pEXpCPbBf@dE@JD^^nC?FFZFn@Hd@\\`CV~BNrA\\rDVfCPfAR~@jDnPZbAXd@Zd@Tj@v@tAHZDZs@m@m@w@MWi@IsDe@yJoA{Bg@iASqAWCHCN}AdI?@CNYpCXqCBO?A|AeIBOBIpAVhARzBf@xJnArDd@V_@m@sBo@sC_DeOG_@UcBk@aGOqAW}Bc@iDGg@Km@]qCE]AIsA}Lm@qFCUQyAY{BKq@Oa@o@uAi@y@{@iAkAwAmB_C{CgDgEkFuDgFcBiCcA}AqAeCo@wAO]aAwB_E{HkA{ByH{NeAuBOY_DgGIO_GaMk@qAa@kA[cAa@oBe@kCa@mBq@{Bq@mBACGSCK{@uCWeAQw@{@uDU_Ac@gBwAgHoAgHk@eDg@oCs@cDIu@OiBUmEs@_HKmAw@yGY_EMwAK_AMg@Qg@]q@c@s@uBcCu@s@aA{@qAk@q@SiAUmBYmDk@qBa@qBi@_GiBaGyBsFgBwBm@wCu@aBg@SKw@i@MO]g@]o@K[QaAOuAOqCEw@E{B@K@MHc@Xy@Zs@vBqEx@oB`@_A^q@d@oA`@cAj@wAb@qAz@sCh@{BfBmID_@DWpAiJNeC@{AEi@YqDGmE?Q?GQkFCKIeCAMCeAQ{EAMDQLKJEj@DlBp@l@RTJ^PlB`Aj@b@~A`Al@b@\\J^V`Ah@H]DSBI@QAo@?c@]oR?_@XgKB]AEJwDZcJPmEPyBP_BRqBJ}@Fm@DoAEaAi@cIo@sKQ{BU_@GAIGAE@KHIj@yBRcA@CBGv@_Dp@}C|BkMVaBf@mCj@cDZ_BB{AAkCEcAAQAmBDe@Ny@~@oFBMFa@fAgFl@iCDKn@sC`@aCJa@h@uBZ}@n@qBFa@@e@^kDjAgILoA?o@HcCBWFaA`@iD@A?M@QR}CZ_DfCmXBc@@{@QwAAa@QeAEOPG|EgBb@SfB_Af@[TQt@o@z@u@dAqBj@eATc@FKNYtA{C`DsG^w@bBgDBEDIRc@@EnAwCbA_Cf@mA`@aAx@mBxBcG@CL]v@eCn@iB~CgI^cAZy@FOVu@Rm@bA_DNg@j@eBh ...
#     'way_points': [0,
#      481,
#      968,
#      1655,
#      2142,
#      2265,
#      2280,
#      3194,
#      4172,
#      4646,
#      4889,
#      5113,
#      5466,
#      6038,
#      6597,
#      7545,
#      8343,
#      8888,
#      9117,
#      9497,
#      10060,
#      10788,
#      11092,
#      11385,
#      11671,
#      12168,
#      12427,
#      12897,
#      13962,
#      14516,
#      14847,
#      15532,
#      15712,
#      16470,
#      17232,
#      18022,
#      18208,
#      19075,
#      19874,
#      19930,
#      20053,
#      20726,
#      20937,
#      21546,
#      21686,
#      22482,
#      23169,
#      23815,
#      23949,
#      24358,
#      25069,
#      25418,
#      25700,
#      26015,
#      26232,
#      26651,
#      27171,
#      27382,
#      27936,
#      28341,
#      29086,
#      30135,
#      30760,
#      31410,
#      31742,
#      31933,
#      32132,
#      32431,
#      32525,
#      32974,
#      33110,
#      33410,
#      33760,
#      33990,
#      34136,
#      34552,
#      35241,
#      35568,
#      35719,
#      35976,
#      36463,
#      37368,
#      38305,
#      38817,
#      39030,
#      39275,
#      39780,
#      40049,
#      40138,
#      40623,
#      41286,
#      42085,
#      43254,
#      43460,
#      43961,
#      44361,
#      44664,
#      45056,
#      45238,
#      45521,
#      45764,
#      46216,
#      46833,
#      47793,
#      48775,
#      48828,
#      49141,
#      49654,
#      49666,
#      49984,
#      50075,
#      50242,
#      50296,
#      50894,
#      51286,
#      51804,
#      52175,
#      52623,
#      52855,
#      53465,
#      53938,
#      54207,
#      54899,
#      55347,
#      55699,
#      55856,
#      56128,
#      56328,
#      56520,
#      56593,
#      56746,
#      56980,
#      57296,
#      57677,
#      57789,
#      58115,
#      58238,
#      58457,
#      58675,
#      58830,
#      58940,
#      59305,
#      60114,
#      60911,
#      61341,
#      61884,
#      62057,
#      62284,
#      62583,
#      63753,
#      64788,
#      65723,
#      66871,
#      67011,
#      67259,
#      67315,
#      67505,
#      67870,
#      68047,
#      68480,
#      69076,
#      69696,
#      69756,
#      70426,
#      70633,
#      70703,
#      70846,
#      71133,
#      71338,
#      71780,
#      72213,
#      72829,
#      73372,
#      73728,
#      73831,
#      74085,
#      74447,
#      74585,
#      74686,
#      74935,
#      75165,
#      75404,
#      75503,
#      75613,
#      75755,
#      75793,
#      76001,
#      76081,
#      76870,
#      77274,
#      77627]}],
#   'metadata': {'attribution': 'openrouteservice.org, OpenStreetMap contributors, tmc - BASt',
#    'service': 'routing',
#    'timestamp': 1737106561337,
#    'query': {'coordinates': [[110.1590859917819, -6.961604658199477],
#      [110.309, -6.97933],
#      [110.087, -6.951],
#      [110.285, -7.0392],
#      [110.203, -6.98042],
#      [110.194, -6.97953],
#      [110.191, -6.97949],
#      [110.096, -7.07028],
#      [110.044, -6.96548],
#      [110.188, -6.95293],
#      [110.111, -6.98167],
#      [110.183, -6.95669],
#      [110.102, -7.01995],
#      [110.204, -6.94442],
#      [110.287, -7.06367],
#      [110.024, -6.94227],
#      [110.223, -7.01326],
#      [110.129, -6.93466],
#      [110.226, -6.91124],
#      [110.126, -7.01352],
#      [110.206, -7.10968],
#      [110.246, -6.95317],
#      [110.207, -6.86541],
#      [110.127, -6.90016],
#      [110.061, -6.93615],
#      [110.185, -6.98499],
#      [110.235, -6.95147],
#      [110.23, -7.06869],
#      [110.05, -6.91422],
#      [110.205, -6.92014],
#      [110.089, -6.93788],
#      [110.352, -6.97214],
#      [110.369, -6.9837],
#      [110.105, -6.90632],
#      [110.254, -7.0827],
#      [110.105, -6.97643],
#      [110.067, -6.94861],
#      [110.238, -7.1014],
#      [110.116, -6.96025],
#      [110.113, -6.97128],
#      [110.068, -6.98063],
#      [110.227, -7.03157],
#      [110.165, -6.9792],
#      [110.361, -6.99433],
#      [110.349, -7.00474],
#      [110.182, -7.09272],
#      [110.322, -7.03125],
#      [110.186, -6.92013],
#      [110.171, -6.90233],
#      [110.24, -6.9889],
#      [110.098, -7.01116],
#      [110.155, -6.92609],
#      [110.29, -6.93883],
#      [110.173, -6.90954],
#      [110.214, -6.95558],
#      [110.248, -7.06515],
#      [110.183, -6.96525],
#      [110.176, -6.93749],
#      [110.373, -6.96852],
#      [110.308, -7.03677],
#      [110.132, -7.10436],
#      [110.097, -6.95697],
#      [110.258, -7.04903],
#      [110.132, -6.9935],
#      [110.194, -6.99882],
#      [110.19, -6.9325],
#      [110.129, -6.977],
#      [110.184, -6.87667],
#      [110.173, -6.87112],
#      [110.054, -6.94614],
#      [110.044, -6.94772],
#      [110.132, -6.92382],
#      [110.028, -6.95823],
#      [110.151, -6.97608],
#      [110.176, -6.92303],
#      [110.341, -6.9888],
#      [110.067, -6.92302],
#      [110.133, -6.97694],
#      [110.159, -6.91451],
#      [110.233, -6.91759],
#      [110.05, -6.93168],
#      [110.193, -7.08361],
#      [110.048, -6.97465],
#      [110.203, -6.97025],
#      [110.153, -6.9617],
#      [110.218, -6.97549],
#      [110.074, -6.9265],
#      [110.164, -6.93167],
#      [110.144, -6.94979],
#      [110.292, -6.99752],
#      [110.059, -6.92749],
#      [110.062, -7.02433],
#      [110.255, -6.97828],
#      [110.286, -6.97022],
#      [110.087, -6.97955],
#      [110.194, -6.94767],
#      [110.104, -6.93622],
#      [110.175, -6.97022],
#      [110.23, -6.96957],
#      [110.182, -6.9114],
#      [110.242, -6.96123],
#      [110.363, -6.97566],
#      [110.164, -6.94743],
#      [110.076, -7.04375],
#      [110.194, -6.93794],
#      [110.205, -6.93196],
#      [110.2672, -7.01665],
#      [110.164, -6.88801],
#      [110.166, -6.88359],
#      [110.129, -6.98797],
#      [110.098, -6.96702],
#      [110.153, -6.98685],
#      [110.167, -6.98669],
#      [110.041, -6.93494],
#      [110.208, -6.95034],
#      [110.053, -6.99836],
#      [110.146, -6.93411],
#      [110.311, -6.95548],
#      [110.342, -6.96912],
#      [110.146, -6.95746],
#      [110.319, -6.95808],
#      [110.315, -6.99529],
#      [110.082, -6.94035],
#      [110.26, -6.95744],
#      [110.117, -6.93751],
#      [110.157, -6.89532],
#      [110.121, -6.97646],
#      [110.182, -6.92827],
#      [110.194, -6.87702],
#      [110.187, -6.90686],
#      [110.172, -6.94346],
#      [110.166, -6.87195],
#      [110.105, -6.94588],
#      [110.175, -6.95882],
#      [110.167, -7.00551],
#      [110.209, -6.90244],
#      [110.216, -6.93745],
#      [110.14, -6.96539],
#      [110.206, -6.9149],
#      [110.156, -6.94638],
#      [110.149, -7.00014],
#      [110.069, -6.94018],
#      [110.216, -7.09337],
#      [110.105, -6.92391],
#      [110.011, -6.92634],
#      [110.217, -6.95917],
#      [110.158, -6.99306],
#      [110.106, -6.99475],
#      [110.125, -6.94652],
#      [110.161, -7.07705],
#      [110.073, -7.00857],
#      [110.131, -7.07626],
#      [110.169, -6.92072],
#      [110.154, -6.89646],
#      [110.14, -6.97686],
#      [110.13, -6.96538],
#      [110.194, -6.91816],
#      [110.106, -6.9149],
#      [110.147, -6.92098],
#      [110.33, -6.96249],
#      [110.123, -6.98535],
#      [110.321, -7.01288],
#      [110.331, -7.00259],
#      [110.162, -6.89662],
#      [110.165, -6.9636],
#      [110.137, -6.95396],
#      [110.147, -6.89811],
#      [110.197, -6.95842],
#      [110.214, -6.90101],
#      [110.217, -6.99357],
#      [110.208, -7.05789],
#      [110.217, -6.91121],
#      [110.03, -6.92396],
#      [110.158, -7.01667],
#      [110.187, -6.99185],
#      [110.228, -6.95061],
#      [110.062, -6.94285],
#      [110.12, -6.95243],
#      [110.155, -6.96661],
#      [110.202, -6.92278],
#      [110.139, -7.00171],
#      [110.199, -6.91895],
#      [110.221, -6.94062],
#      [110.189, -6.92475],
#      [110.142, -6.94344],
#      [110.138, -6.9335],
#      [110.096, -6.92006],
#      [110.074, -6.93454],
#      [110.306, -7.05165],
#      [110.262, -6.92679],
#      [110.1590859917819, -6.961604658199477]],
#     'profile': 'driving-hgv',
#     'preference': 'recommended',
#     'format': 'json',
#     'units': 'km',
#     'geometry': True,
#     'radiuses': [-1.0]},
#    'engine': {'version': '8.0.0',
#     'build_date': '2024-03-21T13:55:54Z',
#     'graph_date': '2024-12-13T07:48:53Z'}}}]

# %%
""" Kode ini belum selesai untuk memperoleh rute random dari seluruh DC"""
# # Inisialisasi dictionary untuk menyimpan semua random_route per DC
# all_random_routes = {}

# # Iterasi melalui data_by_dc
# for label, data_dc in data.items():
#     # Tambahkan koordinat awal sebagai koordinat akhir untuk menutup rute
#     village_coords = data_dc['locations'] + [data_dc['locations'][0]]

#     # Permintaan API untuk rute random
#     request = {
#         'coordinates': village_coords,
#         'geometry': 'true',
#         'radiuses': -1,
#         'preference': 'shortest',
#         'units': units
#     }

#     # Kirim permintaan POST ke API
#     response = requests.post(url=url_direction, headers=headers, json=request)
    
#     # Pastikan permintaan berhasil dan respons berbentuk JSON
#     if response.status_code == 200:
#         random_route = response.json()
#         print(f"{label} random route successfully added!")
#         all_random_routes[label] = random_route
#     else:
#         random_route = response.json()
#         print(f"Error fetching route for {label} code{response.status_code}: {random_route}")
#         all_random_routes[label] = {}

# %%
""" Kode ini belum selesai untuk memperoleh dan menggambarkan seluruh rute kendaraan di semua DC """


# vehicle_id_list = []
# for dc, inner_dict in coordinates_dict.items():
#     for year in inner_dict.keys():
#         vehicle_id_list.append(year)

# if os.path.exists(vehicle_route_opt):
#     # Jika ada, baca data yang ada dalam file
#     with open(vehicle_route_opt, 'r') as f:
#         result_route_optimal = json.load(f)
# else:
#     # Jika tidak ada, buat file kosong dengan struktur dasar
#     result_route_optimal = []

# # Membuat set untuk vehicle_id yang sudah diproses
# processed_vehicle_ids = set()

# # Mengirimkan request untuk setiap vehicle_id
# for vehicle_id in vehicle_id_list:
#     found = False  # Flag untuk mengecek apakah vehicle_id ditemukan

#     # Cek apakah vehicle_id sudah ada dalam result_route_optimal
#     for entry in result_route_optimal:
#         for dc_data in entry.values():
#             if vehicle_id in dc_data:
#                 found = True
#                 print(f"{vehicle_id} already exists")
#                 processed_vehicle_ids.add(vehicle_id)  # Tandai vehicle_id sebagai sudah diproses
#                 break
#         if found:
#             break

#     if found:
#         continue  # Jika vehicle_id sudah ada, lanjutkan ke vehicle_id berikutnya

#     # Jika vehicle_id belum ada, proses koordinat untuk vehicle_id tersebut
#     dc_processed = set()  # Set untuk melacak DC yang sudah diproses untuk vehicle_id

#     for dc, dc_data in coordinates_dict.items():
#         if vehicle_id in dc_data and vehicle_id not in processed_vehicle_ids:
#             coordinates = dc_data[vehicle_id]
#             print(f"Creating data JSON for {vehicle_id} in {dc}")
#             request['coordinates'] = coordinates
            
#             # Mengirimkan POST request untuk mendapatkan optimal route
#             optimal_route_response = requests.post(url=url_direction, headers=headers, json=request)

#             # Mengonversi response ke format JSON
#             if optimal_route_response.status_code == 200:
#                 optimal_route = optimal_route_response.json()
#                 # Menambahkan hasil response ke dalam list result_route_optimal
#                 vehicle = {f'{vehicle_id}': optimal_route}
#                 result_route_optimal.append({
#                     f'{dc}': vehicle
#                 })
#                 dc_processed.add(dc)  # Tandai DC sebagai sudah diproses
#             else:
#                 json_response = optimal_route_response.json()
#                 print(f"Error with vehicle {vehicle_id} in {dc}: {json_response}")
#                 # Menambahkan error response ke dalam list
#                 error = {
#                     'vehicle_id': vehicle_id,
#                     'error': f"Error {json_response}"
#                 }
#                 result_route_optimal.append({
#                     f'{dc}': error
#                 })
#                 dc_processed.add(dc)

#         else:
#             print(f"Coordinates not found for vehicle {vehicle_id} in {dc}")
#             # Menambahkan error response ke dalam list jika koordinat tidak ditemukan
#             error_not_found = {
#                 'vehicle_id': vehicle_id,
#                 'error': 'Coordinates not found'
#             }
#             result_route_optimal.append({
#                 f'{dc}': error_not_found
#             })
#             dc_processed.add(dc)

#     # Menandai vehicle_id sebagai sudah diproses setelah semua DC selesai diproses
#     processed_vehicle_ids.add(vehicle_id)

#     # Jika semua DC yang memiliki vehicle_id sudah diproses, keluar dari loop utama
#     if len(dc_processed) == len([dc for dc in coordinates_dict if vehicle_id in coordinates_dict[dc]]):
#         print(f"All DCs for {vehicle_id} processed, skipping further API calls.")

#     with open(vehicle_route_opt, 'w') as file_json:
#         json.dump(result_route_optimal, file_json, indent=4)

# print("End of calculation")

# %%
# Daftar vehicle_id yang ingin diproses
vehicle_id_list = [vehicle_id for vehicle_id, coords in coordinates_dict[dc_map].items()]

if os.path.exists(vehicle_route_opt):
    # Jika ada, baca data yang ada dalam file
    with open(vehicle_route_opt, 'r') as f:
        result_route_optimal = json.load(f)
else:
    # Jika tidak ada, buat file kosong dengan struktur dasar
    result_route_optimal = []

# Mengirimkan request untuk setiap vehicle_id
for vehicle_id in vehicle_id_list:
    found = False  # Flag untuk mengecek apakah vehicle_id ditemukan
    for value in result_route_optimal:
        if vehicle_id in value:  # Mengecek apakah vehicle_id adalah kunci dari dictionary
            found = True
            print(f"{vehicle_id} already exist")
    if not found:
        print(f"{vehicle_id} Not found in {vehicle_route_opt}")
        print(f"Creating data JSON for {vehicle_id}")
        if vehicle_id in coordinates_dict[dc_map]:
            coordinates = coordinates_dict[dc_map][vehicle_id]
            request['coordinates'] = coordinates
            
            # Mengirimkan POST request untuk mendapatkan optimal route
            optimal_route_response = requests.post(url=url_direction, headers=headers, json=request)

            # Mengonversi response ke format JSON
            if optimal_route_response.status_code == 200:
                optimal_route = optimal_route_response.json()
                # Menambahkan hasil response ke dalam list result_route_optimal
                result_route_optimal.append({
                    f'{vehicle_id}': optimal_route
                })
            else:
                print(f"Error with vehicle {vehicle_id}: {optimal_route_response.status_code}")
                # Menambahkan error response ke dalam list
                result_route_optimal.append({
                    'vehicle_id': vehicle_id,
                    'error': f"Error {optimal_route_response.status_code}"
                })
        else:
            print(f"Coordinates not found for vehicle {vehicle_id}")
            # Menambahkan error response ke dalam list jika koordinat tidak ditemukan
            result_route_optimal.append({
                'vehicle_id': vehicle_id,
                'error': 'Coordinates not found'
            })
        with open(vehicle_route_opt,'w') as file_json:
            json.dump(result_route_optimal, file_json, indent=4)


print("end of calculation")
# Out:
# 1645 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1645
# 1646 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1646
# 1647 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1647
# 1648 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1648
# 1649 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1649
# 1650 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1650
# 1651 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1651
# 1652 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1652
# 1653 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1653
# 1654 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1654
# 1655 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1655
# 1656 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1656
# 1657 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1657
# 1658 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1658
# 1659 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1659
# 1660 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1660
# 1661 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1661
# 1662 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1662
# 1663 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1663
# 1664 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1664
# 1665 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1665
# 1666 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1666
# 1667 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1667
# 1668 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1668
# 1669 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1669
# 1670 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1670
# 1671 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1671
# 1672 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1672
# 1673 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1673
# 1674 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1674
# 1675 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1675
# 1676 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1676
# 1677 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1677
# 1678 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1678
# 1679 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1679
# 1680 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1680
# 1681 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1681
# 1682 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1682
# 1683 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1683
# 1684 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1684
# 1685 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1685
# 1686 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1686
# 1687 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1687
# 1688 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1688
# 1689 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1689
# 1690 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1690
# 1691 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1691
# 1692 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1692
# 1693 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1693
# 1694 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1694
# 1695 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1695
# 1696 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1696
# 1697 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1697
# 1698 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1698
# 1699 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1699
# 1700 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1700
# 1701 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1701
# 1702 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1702
# 1703 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1703
# 1704 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1704
# 1705 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1705
# 1706 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1706
# 1707 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1707
# 1708 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1708
# 1709 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1709
# 1710 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1710
# 1711 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1711
# 1712 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1712
# 1713 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1713
# 1714 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1714
# 1715 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1715
# 1716 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1716
# 1717 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1717
# 1718 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1718
# 1719 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1719
# 1720 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1720
# 1721 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1721
# 1722 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1722
# 1723 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1723
# 1724 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1724
# 1725 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1725
# 1726 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1726
# 1727 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1727
# 1728 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1728
# 1729 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1729
# 1730 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1730
# 1731 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1731
# 1732 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1732
# 1733 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1733
# 1734 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1734
# 1735 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1735
# 1736 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1736
# 1737 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1737
# 1738 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1738
# 1739 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1739
# 1740 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1740
# 1741 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1741
# 1742 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1742
# 1743 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1743
# 1744 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1744
# 1745 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1745
# 1746 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1746
# 1747 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1747
# 1748 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1748
# 1749 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1749
# 1750 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1750
# 1751 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1751
# 1752 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1752
# 1753 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1753
# 1754 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1754
# 1755 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1755
# 1756 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1756
# 1757 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1757
# 1758 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1758
# 1759 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1759
# 1760 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1760
# 1761 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1761
# 1762 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1762
# 1763 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1763
# 1764 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1764
# 1765 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1765
# 1766 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1766
# 1767 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1767
# 1768 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1768
# 1769 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1769
# 1770 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1770
# 1771 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1771
# 1772 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1772
# 1773 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1773
# 1774 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1774
# 1775 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1775
# 1776 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1776
# 1777 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1777
# 1778 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1778
# 1779 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1779
# 1780 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1780
# 1781 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1781
# 1782 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1782
# 1783 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1783
# 1784 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1784
# 1785 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1785
# 1786 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1786
# 1787 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1787
# 1788 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1788
# 1789 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1789
# 1790 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1790
# 1791 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1791
# 1792 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1792
# 1793 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1793
# 1794 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1794
# 1795 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1795
# 1796 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1796
# 1797 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1797
# 1798 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1798
# 1799 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1799
# 1800 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1800
# 1801 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1801
# 1802 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1802
# 1803 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1803
# 1804 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1804
# 1805 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1805
# 1806 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1806
# 1807 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1807
# 1808 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1808
# 1809 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1809
# 1810 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1810
# 1811 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1811
# 1812 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1812
# 1813 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1813
# 1814 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1814
# 1815 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1815
# 1816 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1816
# 1817 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1817
# 1818 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1818
# 1819 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1819
# 1820 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1820
# 1821 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1821
# 1822 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1822
# 1823 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1823
# 1824 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1824
# 1825 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1825
# 1826 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1826
# 1827 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1827
# 1828 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1828
# 1829 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1829
# 1830 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1830
# 1831 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1831
# 1832 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1832
# 1833 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1833
# 1834 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1834
# 1835 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1835
# 1836 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1836
# 1837 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1837
# 1838 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1838
# 1839 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1839
# 1840 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1840
# 1841 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1841
# 1842 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1842
# 1843 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1843
# 1844 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1844
# 1845 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1845
# 1846 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1846
# 1847 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1847
# 1848 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1848
# 1849 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1849
# 1850 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1850
# 1851 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1851
# 1852 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1852
# 1853 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1853
# 1854 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1854
# 1855 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1855
# 1856 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1856
# 1857 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1857
# 1858 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1858
# 1859 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1859
# 1860 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1860
# 1861 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1861
# 1862 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1862
# 1863 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1863
# 1864 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1864
# 1865 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1865
# 1866 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1866
# 1867 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1867
# 1868 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1868
# 1869 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1869
# 1870 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1870
# 1871 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1871
# 1872 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1872
# 1873 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1873
# 1874 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1874
# 1875 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1875
# 1876 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1876
# 1877 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1877
# 1878 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1878
# 1879 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1879
# 1880 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1880
# 1881 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1881
# 1882 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1882
# 1883 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1883
# 1884 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1884
# 1885 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1885
# 1886 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1886
# 1887 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1887
# 1888 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1888
# 1889 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1889
# 1890 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1890
# 1891 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1891
# 1892 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1892
# 1893 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1893
# 1894 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1894
# 1895 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1895
# 1896 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1896
# 1897 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1897
# 1898 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1898
# 1899 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1899
# 1900 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1900
# 1901 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1901
# 1902 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1902
# 1903 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1903
# 1904 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1904
# 1905 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1905
# 1906 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1906
# 1907 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1907
# 1908 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1908
# 1909 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1909
# 1910 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1910
# 1911 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1911
# 1912 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1912
# 1913 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1913
# 1914 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1914
# 1915 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1915
# 1916 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1916
# 1917 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1917
# 1918 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1918
# 1919 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1919
# 1920 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1920
# 1921 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1921
# 1922 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1922
# 1923 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1923
# 1924 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1924
# 1925 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1925
# 1926 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1926
# 1927 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1927
# 1928 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1928
# 1929 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1929
# 1930 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1930
# 1931 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1931
# 1932 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1932
# 1933 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1933
# 1934 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1934
# 1935 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1935
# 1936 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1936
# 1937 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1937
# 1938 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1938
# 1939 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1939
# 1940 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1940
# 1941 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1941
# 1942 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1942
# 1943 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1943
# 1944 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1944
# 1945 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1945
# 1946 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1946
# 1947 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1947
# 1948 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1948
# 1949 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1949
# 1950 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1950
# 1951 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1951
# 1952 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1952
# 1953 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1953
# 1954 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1954
# 1955 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1955
# 1956 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1956
# 1957 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1957
# 1958 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1958
# 1959 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1959
# 1960 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1960
# 1961 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1961
# 1962 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1962
# 1963 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1963
# 1964 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1964
# 1965 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1965
# 1966 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1966
# 1967 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1967
# 1968 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1968
# 1969 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1969
# 1970 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1970
# 1971 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1971
# 1972 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1972
# 1973 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1973
# 1974 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1974
# 1975 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1975
# 1976 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1976
# 1977 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1977
# 1978 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1978
# 1979 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1979
# 1980 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1980
# 1981 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1981
# 1982 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1982
# 1983 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1983
# 1984 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1984
# 1985 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1985
# 1986 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1986
# 1987 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1987
# 1988 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1988
# 1989 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1989
# 1990 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1990
# 1991 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1991
# 1992 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1992
# 1993 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1993
# 1994 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1994
# 1995 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1995
# 1996 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1996
# 1997 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1997
# 1998 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1998
# 1999 Not found in vehicle_route_opt_DC5_50.json
# Creating data JSON for 1999
# end of calculation

# %%
# # List untuk menyimpan hasil response untuk setiap vehicle_id
# all_result_route_optimal = {}
# # Daftar vehicle_id yang ingin diproses
# for dc, dc_data in coordinates_dict.items():
#     vehicle_id_list = [vehicle_id for vehicle_id, coords in dc_data.items()]
#     result_route_optimal = []

#     # Mengirimkan request untuk setiap vehicle_id
#     for vehicle_id in vehicle_id_list:
#         # Mengambil koordinat berdasarkan vehicle_id dari coordinates_dict
#         if vehicle_id in dc_data:
#             coordinates = dc_data[vehicle_id]
#             request['coordinates'] = coordinates
            
#             # Mengirimkan POST request untuk mendapatkan optimal route
#             optimal_route_response = requests.post(url=url_direction, headers=headers, json=request)

#             # Mengonversi response ke format JSON
#             if optimal_route_response.status_code == 200:
#                 optimal_route = optimal_route_response.json()
#                 # print(f"Optimal route for {vehicle_id}: {optimal_route}")
#                 # Menambahkan hasil response ke dalam list result_route_optimal
#                 result_route_optimal.append({
#                     f'{vehicle_id}': optimal_route
#                 })
#             else:
#                 print(f"Error in DC {dc} of vehicle {vehicle_id}: {optimal_route_response.status_code}")
#                 # Menambahkan error response ke dalam list
#                 result_route_optimal.append({
#                     'vehicle_id': vehicle_id,
#                     'error': f"Error {optimal_route_response.status_code}"
#                 })
#         else:
#             print(f"Coordinates not found for vehicle {vehicle_id}")
#             # Menambahkan error response ke dalam list jika koordinat tidak ditemukan
#             result_route_optimal.append({
#                 'vehicle_id': vehicle_id,
#                 'error': 'Coordinates not found'
#             })
#         all_result_route_optimal[dc] = result_route_optimal

# # Menampilkan semua hasil yang tersimpan di result_route_optimal
# print("Result Route Optimal:")
# print(all_result_route_optimal)

# %%
distance_list = []
duration_list = []
for i, value in enumerate(result_route_optimal):
    for vehicle_id in vehicle_id_list:

        if vehicle_id in value:
            routes = value[vehicle_id]['routes']
            coords = value[vehicle_id]['metadata']['query']['coordinates']
            
            for k, route in enumerate(routes):
                geometry = route['geometry']
                distance = route['summary']['distance']
                duration = route['summary']['duration']
                distance_list.append(distance)
                duration_list.append(duration)

sum_distance = sum(distance_list)
sum_duration = sum(duration_list) / 60
mean_distance = sum(distance_list) / len(distance_list)
mean_duration = (sum(duration_list) / 60) / len(duration_list)

print(f"Sum of Distance {preference}: {sum_distance:.0f} {units}")
print(f"Sum of Duration {preference}: {math.ceil(sum_duration):.0f} hours")

print(f"\nAverage of Distance {preference}: {mean_distance:.0f} {units}")
print(f"Average of Duration {preference}: {mean_duration:.0f} hours")

print(f"\nNumber of Amount Trips before optimization in {dc_map} {(sum(data_dc['alokasi_per_bulan']) + 183) / 8:.0f}")
print(f"Number of Amount Trips after optimization in {dc_map}: {len(vehicle_id_list)}")
# Out:
# Sum of Distance recommended: 10080 km
# Sum of Duration recommended: 13591 hours
#
# Average of Distance recommended: 28 km
# Average of Duration recommended: 38 hours
#
# Number of Amount Trips before optimization in DC5 374
# Number of Amount Trips after optimization in DC5: 355
# 373.94249999999903

# %%
depot_loc = data_dc[['DC_longitude','DC_latitude']].head(1).values.tolist()
consumer_loc = data_dc[['lon_customers', 'lat_customers']].iloc[1:].values.tolist()

depot_coord = [depot_loc[0][0], depot_loc[0][1]]
def color_depot(coords, default_color):
    if coords == depot_coord:
        return "red"
    else:
        return default_color

def icon_depot(coords, default_icon):
    if coords == depot_coord:
        return "home"
    else:
        return default_icon

def layer_control(coords, name, control=True, show=True):
    if coords == depot_coord:
        fg = folium.FeatureGroup(name, control==False, show)
    else:
        fg = folium.FeatureGroup(name, control==control, show)
    return fg

# %%
m = folium.Map(location=(data_dc['lat_customers'].mean(), data_dc['lon_customers'].mean()), zoom_start=8)
fg_icon = folium.FeatureGroup(name='Icon Collection', show=True).add_to(m)
fg_line = folium.FeatureGroup(name='Route', show=False).add_to(m)
fg_line_opt = folium.FeatureGroup(name='Route Optimization', show=False).add_to(m)
marker_cluster_icon = MarkerCluster().add_to(fg_icon)
marker_cluster_line = MarkerCluster().add_to(fg_line)
marker_cluster_opt = MarkerCluster().add_to(fg_line_opt)
folium.map.LayerControl().add_to(m)

# marker icon
for _,row in data_dc.iterrows():
    name = row['customers']
    lat = row['lat_customers']
    lon = row['lon_customers']
    coords = [lat,lon]

    reversed_coords = list(reversed(coords))
    popup = "<strong>{0}</strong><br>Lat: {1:.3f}<br>Long: {2:.3f}".format(name, lat, lon)
    icon = folium.Icon(
        color=color_depot(reversed_coords,"blue"),
        icon_color='white',
        icon=icon_depot(reversed_coords,"info"),  # fetches font-awesome.io symbols
        prefix='fa')
    folium.Marker(coords, icon=icon, popup=popup).add_to(fg_icon)

# marker icon FOR DEPOT
dc_lat = float(data_dc.iloc[0]['DC_latitude'])
dc_lon = float(data_dc.iloc[0]['DC_longitude'])
dc_lon_lat = [dc_lon, dc_lat]

popup = "<strong>{0}</strong><br>Lat: {1:.3f}<br>Long: {2:.3f}".format(name, lat, lon)
icon = folium.Icon(
    color=color_depot(dc_lon_lat,"blue"),
    icon_color='white',
    icon=icon_depot(dc_lon_lat,"info"),  # fetches font-awesome.io symbols
    prefix='fa')
folium.Marker([dc_lat,dc_lon], icon=icon, popup=popup).add_to(fg_icon)

# get random route using direction API Open Route Service
line_colors = ['green', 'orange', 'blue', 'yellow']

decode_geometries = []
# Loop untuk mendekode setiap geometry dari alternatif rute (enumerate untuk bentuk list)
for i, responses in enumerate(random_route):
    color = line_colors[i % len(line_colors)]
    routes = responses['routes']
    coords = responses['metadata']['query']['coordinates']
    # preference = responses['preference']

    for j, route in enumerate(routes):
        geometry = route['geometry']
        distance = route['summary']['distance']
        duration = route['summary']['duration']
        decoded = decode_polyline(geometry)['coordinates']  # Decode geometry
        decode_geometries.append(decoded)  # Simpan ke daftar
        for i, coord in enumerate(coords):
            line = folium.PolyLine(
                locations=[list(reversed(coord)) for coord in decoded],
                color=color,
                weight=5,
                opacity=0.5,
                popup=f"Distance:{distance}{units} \n Duration:{duration / 60:.2f}min"
            )
            marker_cluster_line.add_child(line)

# Memuat file JSON dan mengonversinya menjadi list
color_codes_json_path = 'color_codes.json'

with open(color_codes_json_path, 'r') as file:
    color_codes = json.load(file)

line_colors_opt = color_codes

# get optimize route using direction API Open Route Service based on sequence coordinate OR-TOOLS
for i, value in enumerate(result_route_optimal):
    for vehicle_id in vehicle_id_list:
        color = line_colors_opt[i % len(line_colors_opt)]
        # Periksa jika vehicle_id ada di value
        if vehicle_id in value:
            routes = value[vehicle_id]['routes']
            coords = value[vehicle_id]['metadata']['query']['coordinates']
            
            for k, route in enumerate(routes):
                geometry = route['geometry']
                distance = route['summary']['distance']
                duration = route['summary']['duration']
                decoded = decode_polyline(geometry)['coordinates']
                for i, coord in enumerate(coords):
                    line_opt = folium.PolyLine(
                        locations=[list(reversed(coord)) for coord in decoded],
                        color=color,
                        weight=2,
                        opacity=0.7,
                        popup=f"Distance:{distance}{units} \n Duration:{duration / 60:.2f}min",
                    )
                    marker_cluster_opt.add_child(line_opt)
m.save(file_map)
